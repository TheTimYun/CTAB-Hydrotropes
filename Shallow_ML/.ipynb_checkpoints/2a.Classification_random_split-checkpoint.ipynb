# %% [markdown]
# **Overview**
# This notebook describes folloiwing stages:
# 1. Creating functions to:
#     - perform search for optimal algorithm parameters;
#     - train model;
#     - calculate the most important metrics;
#     - plot ROC-AUC curve
# 2. Assess the results of following algorithms:
#     - Logistic regression;
#     - Random Forest;
#     - Gradient Boosting as implemented in XGBoost;
#     - Support Vector Machines;
#     - K-Nearest Neighborrs
# 3. Creare dataframe with the main indiators of models' performance

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score, precision_score, roc_curve, recall_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# First, let's import datasets and y-target, created earlier:

# %%
with open('X_padel.pickle', 'rb') as input:
    X_padel = pickle.load(input)

# %%
with open('X_standard.pickle', 'rb') as input:
    X_standard = pickle.load(input)

# %%
with open('y.pickle', 'rb') as input:
    target = pickle.load(input)

# %%
with open('X_standard.pickle', 'rb') as input:
    X_standard_pca = pickle.load(input)

# %%
with open('X_padel.pickle', 'rb') as input:
    X_padel_pca = pickle.load(input)

# %% [markdown]
# Remove all temperatures higher than 30 C

# %% [markdown]
# To facilitate automatic calculation of metrics and asiggning labels, we weill create dictionaries with imported descriptors datasets (standard datasets and datasetes with reduced dimensionality)

# %%
descriptors_dict = {'Standard':X_standard, 'Padel':X_padel}

# %%
descriptors_dict_pca = {'Standard':X_standard, 'Padel':X_padel}

# %%
scores = {'Descriptors':[], 'Full or PCA':[], 'Presicion_CV':[], 'Stddev_CV':[], 'Accuracy':[], 'F1 - score':[], 'ROC-AUC Score':[], 'Estimator':[], 'Recall score':[], 'Precision score':[]}

# %% [markdown]
# The function below performs multiple tasks:
# 1. First, it create matplotlib figure object and axes with two fields,
# 2. Then for each of two datasets in descriptors dictionary (standard and PCA), we:
#     - Create a pipeline, made of MinMaxScaler and algorithm,
#     - Split dataset into training and testing subsets;
#     - Then we search for optimal parameters with functions from [hyperopt package](http://hyperopt.github.io/hyperopt/);
#     - Then we extract the best model and train it with X_train and y_train;
#     - Then we claculate different metrics (Accuracy, F1-Score, ROC_AUC score) and append it to the special dictionary with results, as well as some information abour descriptors sets and name of studied algorithm
#     - Finally, we plot ROC-AUC curve

# %%
def calculate_to_score(pipe, estimator_name, param_grid, descriptors_dict = descriptors_dict, target=target, type = 'Full'):
    fig, axes = plt.subplots(1, 2, figsize = (16,8))
    i = 0
    for key, value in descriptors_dict.items():
        X_train, X_test, y_train, y_test = train_test_split(value, target, random_state = 0)
        def objective(params, X, target):
            #pipe = make_pipeline(MinMaxScaler(), estimator)
            pipe.set_params(**params)
            score = cross_val_score(pipe, X, target, cv = 10, scoring = 'precision')
            return {'loss':-score.mean(), 'stddev':score.std(),  'status':STATUS_OK, 'Trained_model':pipe}
        trials = Trials()
        best = fmin(partial(objective, X = X_train, target = y_train), space = param_grid, trials = trials, algo = tpe.suggest, max_evals=  50)
        print(best)
        best_model_and_properties = get_best_model_from_trials(trials)

        
        print('Loss is {}'.format(best_model_and_properties[2]))
        print('Standard deviation is {}'.format(best_model_and_properties[1]))
        best_estimator  = best_model_and_properties[0]
        scores['Presicion_CV'].append(best_model_and_properties[2])
        scores['Stddev_CV'].append(best_model_and_properties[1])


        
        best_estimator.fit(X_train, y_train)
        predictions = best_estimator.predict(X_test)
        probs = best_estimator.predict_proba(X_test)[:,1]
        scores['Descriptors'].append(key)
        scores['Accuracy'].append(accuracy_score(y_test, predictions))
        scores['F1 - score'].append(f1_score(y_test, predictions))
        scores['ROC-AUC Score'].append(roc_auc_score(y_test, probs))
        scores['Recall score'].append(recall_score(y_test, predictions))
        scores['Precision score'].append(precision_score(y_test, predictions))
        scores['Full or PCA'].append(type)
        scores['Estimator'].append(estimator_name)
        fpr, tpr, _ = roc_curve(y_test, probs)
        axes[i].plot(fpr, tpr)
        axes[i].plot([0,1],[0,1], 'k--')
        axes[i].set_xlim(0,1)
        axes[i].set_ylim(0,1)
        axes[i].set_title('ROC-AUC Curve for {} descriptors'.format(key))
        axes[i].set_xlabel('False positive rate')
        axes[i].set_ylabel('True positive rate')
        i += 1
    plt.tight_layout()
    plt.savefig('ROC_AUC_all_temps_random/'+estimator_name+'_'+type+'.png')

# %% [markdown]
# Subfunction below is to retrieve best model from Trials object ans is used in main functions

# %%
def get_best_model_from_trials(trials):
    valid_trial_list = [trial for trial in trials if trial['result']['status'] == STATUS_OK]
    losses = [ float(trial['result']['loss']) for trial in valid_trial_list]
    index_having_minumum_loss = np.argmin(losses)
    best_trial_obj = valid_trial_list[index_having_minumum_loss]
    return best_trial_obj['result']['Trained_model'], best_trial_obj['result']['stddev'], -best_trial_obj['result']['loss']

# %% [markdown]
# Let's initialize scores dictionary and test function with Logistic Regression

# %%
pipe = Pipeline([('var_sel', VarianceThreshold(threshold=0.1)), ('scaler', StandardScaler()), 
                 ('logisticregression',LogisticRegression(max_iter=10000))])

# %%
param_grid = {'var_sel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4), 
             'logisticregression__C':hp.loguniform(label = 'C', low = -4*np.log(10), high  = 2*np.log(10))}

# %%
calculate_to_score(pipe, estimator_name='Logistic Regression', 
                   param_grid = param_grid)
# Out:
# 100%|██████████| 50/50 [01:33<00:00,  1.87s/trial, best loss: -0.7347769532926953]
# {'C': 99.36795887458716, 'threshold': 0.0034190994028636458}
# Loss is 0.7347769532926953
# Standard deviation is 0.053371511489742784
# 100%|██████████| 50/50 [01:13<00:00,  1.47s/trial, best loss: -0.7504517527561005]
# {'C': 0.05857418697179284, 'threshold': 0.18692223189144047}
# Loss is 0.7504517527561005
# Standard deviation is 0.04330836575122033

# %%
calculate_to_score(pipe, estimator_name='Logistic Regression', 
                   param_grid = param_grid,
                  descriptors_dict=descriptors_dict_pca, type = 'PCA')
# Out:
# 100%|██████████| 50/50 [01:01<00:00,  1.23s/trial, best loss: -0.7324239440109006]
# {'C': 0.031817112489741325, 'threshold': 0.0478038755510917}
# Loss is 0.7324239440109006
# Standard deviation is 0.06620939255002634
# 100%|██████████| 50/50 [01:16<00:00,  1.53s/trial, best loss: -0.7493675213675214]
# {'C': 0.08421954988127024, 'threshold': 0.39757895109210983}
# Loss is 0.7493675213675214
# Standard deviation is 0.03642162846452579

# %% [markdown]
# Let's continue with other models. The first one will be
# **Random Forest Classification**

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),('randomforest', RandomForestClassifier(n_jobs = -1))])

# %%
space={'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
    'randomforest__max_depth':hp.randint('max_depth',1,50),  'randomforest__max_features':hp.choice('max_features', [None, 'sqrt', 'log2']),
       'randomforest__min_samples_split':hp.randint('min_samples_split', 2, 8),
       'randomforest__min_samples_leaf': hp.randint('min_samples_leaf', 1, 10),
      'randomforest__n_estimators':hp.randint('n_estimators',50, 500),
      'randomforest__criterion': hp.choice('criterion', ["gini", "entropy", "log_loss"])}

# %%
calculate_to_score(pipe, estimator_name = 'Random Forest', param_grid =  space,
                   descriptors_dict=descriptors_dict,
                   target=target,type = 'Full')
# Out:
# 100%|██████████| 50/50 [26:17<00:00, 31.55s/trial, best loss: -0.8052352104653894]
# {'criterion': 1, 'max_depth': 14, 'max_features': 0, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 316, 'threshold': 0.057954357808309626}
# Loss is 0.8052352104653894
# Standard deviation is 0.05798324989863106
# 100%|██████████| 50/50 [28:22<00:00, 34.05s/trial, best loss: -0.8203839905327319]
# {'criterion': 1, 'max_depth': 37, 'max_features': 0, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 59, 'threshold': 0.053716622360994885}
# Loss is 0.8203839905327319
# Standard deviation is 0.046310104161222505

# %%
calculate_to_score(pipe, estimator_name = 'Random Forest', param_grid =  space,
                   descriptors_dict=descriptors_dict_pca,
                   target=target,                   type = 'PCA')
# Out:
# 100%|██████████| 50/50 [26:26<00:00, 31.72s/trial, best loss: -0.8110272893856102]
# {'criterion': 1, 'max_depth': 33, 'max_features': 0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 133, 'threshold': 0.22823326007870504}
# Loss is 0.8110272893856102
# Standard deviation is 0.06655974472584662
# 100%|██████████| 50/50 [31:32<00:00, 37.85s/trial, best loss: -0.8255067677893765]
# {'criterion': 0, 'max_depth': 38, 'max_features': 0, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 301, 'threshold': 0.33128179197481983}
# Loss is 0.8255067677893765
# Standard deviation is 0.039981854467801406

# %% [markdown]
# **XGBoost**

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),('xgbclassifier', XGBClassifier(n_jobs = -1))])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
        'xgbclassifier__n_estimators':hp.randint('n_estimators', 1, 30),
         'xgbclassifier__learning_rate': hp.loguniform('learning_rate', low = -4*np.log(10), high  = 2*np.log(10)),
         'xgbclassifier__reg_alpha':hp.loguniform(label = 'reg_alpha', low = -4*np.log(10), high  = 2*np.log(10)),
         'xgbclassifier__max_depth':hp.randint('max_depth', 1, 100)}

# %%
calculate_to_score(pipe, estimator_name='Gradient boosting', param_grid = space,
                   descriptors_dict=descriptors_dict,
                   target=target,
                   type = 'Full')
# Out:
#   6%|▌         | 3/50 [00:20<06:16,  8.00s/trial, best loss: -0.7860804139499792]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  16%|█▌        | 8/50 [00:41<03:14,  4.64s/trial, best loss: -0.7860804139499792]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  24%|██▍       | 12/50 [01:06<04:23,  6.95s/trial, best loss: -0.7860804139499792]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  38%|███▊      | 19/50 [01:36<02:35,  5.02s/trial, best loss: -0.7860804139499792]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  64%|██████▍   | 32/50 [03:07<02:09,  7.18s/trial, best loss: -0.8224246156142708]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  86%|████████▌ | 43/50 [04:32<01:00,  8.59s/trial, best loss: -0.8224246156142708]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|██████████| 50/50 [05:14<00:00,  6.30s/trial, best loss: -0.825004104591061]
# {'learning_rate': 0.18648261433474597, 'max_depth': 85, 'n_estimators': 24, 'reg_alpha': 0.6408205710449673, 'threshold': 0.36488403145207016}
# Loss is 0.825004104591061
# Standard deviation is 0.053835213707435534
#  16%|█▌        | 8/50 [00:57<05:04,  7.26s/trial, best loss: -0.8168082223734399]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  22%|██▏       | 11/50 [01:19<05:22,  8.28s/trial, best loss: -0.8349683327944197]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  28%|██▊       | 14/50 [01:33<03:27,  5.77s/trial, best loss: -0.8349683327944197]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  34%|███▍      | 17/50 [01:51<03:12,  5.84s/trial, best loss: -0.8349683327944197]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  54%|█████▍    | 27/50 [03:17<03:27,  9.00s/trial, best loss: -0.8387906658558834]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  64%|██████▍   | 32/50 [03:54<02:45,  9.20s/trial, best loss: -0.8387906658558834]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  66%|██████▌   | 33/50 [03:59<02:11,  7.75s/trial, best loss: -0.8387906658558834]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  72%|███████▏  | 36/50 [04:40<02:40, 11.49s/trial, best loss: -0.8387906658558834]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  74%|███████▍  | 37/50 [04:45<02:04,  9.58s/trial, best loss: -0.8387906658558834]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  88%|████████▊ | 44/50 [05:55<00:55,  9.28s/trial, best loss: -0.8387906658558834]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|██████████| 50/50 [06:30<00:00,  7.80s/trial, best loss: -0.8562226300269777]
# {'learning_rate': 1.2615477417315089, 'max_depth': 81, 'n_estimators': 10, 'reg_alpha': 0.0023229365419527768, 'threshold': 0.27080481570416526}
# Loss is 0.8562226300269777
# Standard deviation is 0.045426624324864134

# %%
calculate_to_score(pipe, estimator_name='Gradient boosting', param_grid = space,
                   descriptors_dict=descriptors_dict_pca,
                   target=target,
                   type = 'PCA')
# Out:
#   2%|▏         | 1/50 [00:12<10:29, 12.84s/trial, best loss: -0.5254106280193236]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#   6%|▌         | 3/50 [00:21<04:45,  6.07s/trial, best loss: -0.5599455393495872]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  24%|██▍       | 12/50 [01:08<03:33,  5.63s/trial, best loss: -0.7934574025008808]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  34%|███▍      | 17/50 [01:37<03:40,  6.69s/trial, best loss: -0.7974377072203158]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  54%|█████▍    | 27/50 [04:33<08:22, 21.83s/trial, best loss: -0.806336827423784]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  64%|██████▍   | 32/50 [06:37<07:39, 25.52s/trial, best loss: -0.806336827423784]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  96%|█████████▌| 48/50 [12:34<00:38, 19.39s/trial, best loss: -0.806336827423784]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  98%|█████████▊| 49/50 [12:51<00:18, 18.69s/trial, best loss: -0.806336827423784]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|██████████| 50/50 [13:08<00:00, 15.78s/trial, best loss: -0.806336827423784]
# {'learning_rate': 1.1015627292769958, 'max_depth': 7, 'n_estimators': 12, 'reg_alpha': 0.573643652973156, 'threshold': 0.13586371836693822}
# Loss is 0.806336827423784
# Standard deviation is 0.058318454422069045
#  32%|███▏      | 16/50 [03:33<03:25,  6.04s/trial, best loss: -0.8251523331740722]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  44%|████▍     | 22/50 [04:02<02:13,  4.77s/trial, best loss: -0.8251523331740722]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  60%|██████    | 30/50 [05:04<02:11,  6.56s/trial, best loss: -0.8251523331740722]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  66%|██████▌   | 33/50 [05:44<03:20, 11.82s/trial, best loss: -0.8283249866075953]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  90%|█████████ | 45/50 [07:20<00:41,  8.28s/trial, best loss: -0.8435934258977739]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|██████████| 50/50 [07:48<00:00,  9.36s/trial, best loss: -0.8435934258977739]
# {'learning_rate': 0.6289249959339961, 'max_depth': 32, 'n_estimators': 14, 'reg_alpha': 0.03751971387426096, 'threshold': 0.017373679845083024}
# Loss is 0.8435934258977739
# Standard deviation is 0.04817643882899464

# %% [markdown]
# **SVM**

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('model_sel',SelectFromModel(LogisticRegression(max_iter=10000))),
                 ('svc', SVC(probability=True))])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
         'model_sel__estimator__C':hp.loguniform(label = 'alpha', low = -1, high =2),
    'svc__C':hp.loguniform('C', -3*np.log(10), 2*np.log(10)),
         'svc__kernel':hp.choice('kernel', ['rbf','poly','linear', 'sigmoid']),
         'svc__degree':hp.choice('degree', [2,3]),
         'svc__gamma':hp.choice('gamma', ['scale', 'auto']),
         'svc__coef0':hp.loguniform('coef0', -3*np.log(10), 0*np.log(10))}

# %%
calculate_to_score(pipe, estimator_name = 'SVC', param_grid = space, descriptors_dict=descriptors_dict, target = target, type = 'Full')
# Out:
# 100%|██████████| 50/50 [02:05<00:00,  2.52s/trial, best loss: -0.7731432748538011]
# {'C': 0.27783433896441534, 'alpha': 0.4370067669867115, 'coef0': 0.12233861383570384, 'degree': 1, 'gamma': 1, 'kernel': 1, 'threshold': 0.3042080718304059}
# Loss is 0.7731432748538011
# Standard deviation is 0.11138115752589153
# 100%|██████████| 50/50 [02:55<00:00,  3.50s/trial, best loss: -0.7882072452507234]
# {'C': 95.88477048403291, 'alpha': 2.3995524877904346, 'coef0': 0.37833284199249223, 'degree': 0, 'gamma': 0, 'kernel': 1, 'threshold': 0.33537837402250315}
# Loss is 0.7882072452507234
# Standard deviation is 0.05119918701755787

# %%
calculate_to_score(pipe, estimator_name = 'SVC', param_grid = space, descriptors_dict=descriptors_dict_pca, target = target, type = 'PCA')
# Out:
# 100%|██████████| 50/50 [01:50<00:00,  2.21s/trial, best loss: -0.7454333492594362]
# {'C': 78.92399155688892, 'alpha': 0.3885303463813891, 'coef0': 0.010244260712851788, 'degree': 0, 'gamma': 1, 'kernel': 0, 'threshold': 0.27954981668449697}
# Loss is 0.7454333492594362
# Standard deviation is 0.057723521160705726
# 100%|██████████| 50/50 [02:26<00:00,  2.93s/trial, best loss: -0.7668431339885613]
# {'C': 84.20241008031418, 'alpha': 0.3787245881001161, 'coef0': 0.0011262638883203216, 'degree': 1, 'gamma': 0, 'kernel': 1, 'threshold': 0.013163496510990517}
# Loss is 0.7668431339885613
# Standard deviation is 0.060393855753751675

# %% [markdown]
# **KNearestneighbors**

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('model_sel',SelectFromModel(LogisticRegression(max_iter=10000))),
                 ('kneighborsclassifier', KNeighborsClassifier())])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
         'model_sel__estimator__C':hp.loguniform(label = 'alpha', low = -1, high =2),
    'kneighborsclassifier__n_neighbors':hp.randint('n_neighbors',1, 10),
         'kneighborsclassifier__weights':hp.choice('weights', ['uniform', 'distance']),
         'kneighborsclassifier__metric':hp.choice('metric', ['minkowski', 'chebyshev', 'cosine', 'euclidean'])}

# %%
calculate_to_score(pipe, estimator_name='KMeans', param_grid=space, 
                   descriptors_dict=descriptors_dict, target=target, type = 'Full')
# Out:
# 100%|██████████| 50/50 [01:59<00:00,  2.39s/trial, best loss: -0.7373148293364838]
# {'alpha': 0.7333345702188917, 'metric': 1, 'n_neighbors': 6, 'threshold': 0.2878495316926161, 'weights': 1}
# Loss is 0.7373148293364838
# Standard deviation is 0.044401190247489876
# 100%|██████████| 50/50 [03:18<00:00,  3.97s/trial, best loss: -0.7847817673980347]
# {'alpha': 1.2069795870192503, 'metric': 1, 'n_neighbors': 2, 'threshold': 0.12669136624333216, 'weights': 0}
# Loss is 0.7847817673980347
# Standard deviation is 0.08908904194133246

# %%
calculate_to_score(pipe, estimator_name='KMeans', param_grid=space, 
                   descriptors_dict=descriptors_dict_pca, target=target, type = 'PCA')
# Out:
# 100%|██████████| 50/50 [02:09<00:00,  2.59s/trial, best loss: -0.7499828362212263]
# {'alpha': 0.7711063072565293, 'metric': 2, 'n_neighbors': 2, 'threshold': 0.3548512049687824, 'weights': 0}
# Loss is 0.7499828362212263
# Standard deviation is 0.050024171309241
# 100%|██████████| 50/50 [03:03<00:00,  3.68s/trial, best loss: -0.79143963567355]
# {'alpha': 0.579974766844987, 'metric': 1, 'n_neighbors': 2, 'threshold': 0.0932356735265294, 'weights': 0}
# Loss is 0.79143963567355
# Standard deviation is 0.09247280015254479

# %% [markdown]
# Let's save results into pickle file and show the final scores model in readable format

# %%
with open('score_random_all_temp.pickle', 'wb') as output:
    pickle.dump(scores, output)

# %%
pd.DataFrame(scores)
# Out:
#    Descriptors Full or PCA  Presicion_CV  Stddev_CV  Accuracy  F1 - score  \
# 0     Standard        Full      0.773143   0.111381  0.690789    0.725146
# 1        Padel        Full      0.788207   0.051199  0.578947    0.609756
# 2     Standard         PCA      0.745433   0.057724  0.671053    0.705882
# 3        Padel         PCA      0.766843   0.060394  0.671053    0.709302
# 4     Standard        Full      0.734777   0.053372  0.631579    0.670588
# 5        Padel        Full      0.750452   0.043308  0.657895    0.694118
# 6     Standard         PCA      0.732424   0.066209  0.651316    0.678788
# 7        Padel         PCA      0.749368   0.036422  0.710526    0.741176
# 8     Standard        Full      0.805235   0.057983  0.763158    0.783133
# 9        Padel        Full      0.820384   0.046310  0.684211    0.720930
# 10    Standard         PCA      0.811027   0.066560  0.776316    0.795181
# 11       Padel         PCA      0.825507   0.039982  0.815789    0.835294
# 12    Standard        Full      0.825004   0.053835  0.717105    0.745562
# 13       Padel        Full      0.856223   0.045427  0.532895    0.695279
# 14    Standard         PCA      0.806337   0.058318  0.526316    0.446154
# 15       Padel         PCA      0.843593   0.048176  0.756579    0.788571
# 16    Standard        Full      0.737315   0.044401  0.690789    0.734463
# 17       Padel        Full      0.784782   0.089089  0.756579    0.788571
# 18    Standard         PCA      0.749983   0.050024  0.703947    0.730539
# 19       Padel         PCA      0.791440   0.092473  0.743421    0.774566
#
#     ROC-AUC Score            Estimator  Recall score  Precision score
# 0        0.706486                  SVC      0.765432         0.688889
# 1        0.587463                  SVC      0.617284         0.602410
# 2        0.733959                  SVC      0.740741         0.674157
# 3        0.742827                  SVC      0.753086         0.670330
# 4        0.694749  Logistic Regression      0.703704         0.640449
# 5        0.755869  Logistic Regression      0.728395         0.662921
# 6        0.711528  Logistic Regression      0.691358         0.666667
# 7        0.745436  Logistic Regression      0.777778         0.707865
# 8        0.855156        Random Forest      0.802469         0.764706
# 9        0.809859        Random Forest      0.765432         0.681319
# 10       0.868371        Random Forest      0.814815         0.776471
# 11       0.882716        Random Forest      0.876543         0.797753
# 12       0.807512    Gradient boosting      0.777778         0.715909
# 13       0.785950    Gradient boosting      1.000000         0.532895
# 14       0.538167    Gradient boosting      0.358025         0.591837
# 15       0.867501    Gradient boosting      0.851852         0.734043
# 16       0.788385               KMeans      0.802469         0.677083
# 17       0.749870               KMeans      0.851852         0.734043
# 18       0.762215               KMeans      0.753086         0.709302
# 19       0.826378               KMeans      0.827160         0.728261
