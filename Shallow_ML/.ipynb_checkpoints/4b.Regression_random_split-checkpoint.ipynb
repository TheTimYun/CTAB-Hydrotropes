# %% [markdown]
# **Overview**
# This notebook describes folloiwing stages:
# 1. Creating functions to:
#     - perform search for optimal algorithm parameters;
#     - train model;
#     - calculate the most important metrics;
#     - plot ROC-AUC curve
# 2. Assess the results of following algorithms:
#     - Logistic regression;
#     - Random Forest;
#     - Gradient Boosting as implemented in XGBoost;
#     - Support Vector Machines;
#     - K-Nearest Neighborrs
# 3. Creare dataframe with the main indiators of models' performance

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_val_predict
from sklearn.linear_model import Lasso
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score, precision_score, roc_curve, recall_score
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# First, let's import datasets and y-target, created earlier:

# %%
with open('X_padel.pickle', 'rb') as input:
    X_padel = pickle.load(input)

# %%
with open('X_standard.pickle', 'rb') as input:
    X_standard = pickle.load(input)

# %%
with open('viscosity.pickle', 'rb') as input:
    target = pickle.load(input)
target = np.log10(target)

# %%
with open('X_standard.pickle', 'rb') as input:
    X_standard_pca = pickle.load(input)

# %%
with open('X_padel.pickle', 'rb') as input:
    X_padel_pca = pickle.load(input)

# %% [markdown]
# To facilitate automatic calculation of metrics and asiggning labels, we weill create dictionaries with imported descriptors datasets (standard datasets and datasetes with reduced dimensionality)

# %%
descriptors_dict = {'Standard':X_standard, 'Padel':X_padel}

# %%
descriptors_dict_pca = {'Standard':X_standard, 'Padel':X_padel}

# %%
scores = {'Descriptors':[], 'Estimator':[], 'Full or PCA':[], 'RMSE_CV':[], 'Stddev_RMSE_CV':[], 'R2_CV':[], 'MAE_CV':[],  'RMSE_test':[], 'MAE_test':[], 'R2_test':[] }

# %% [markdown]
# The function below performs multiple tasks:
# 1. First, it create matplotlib figure object and axes with two fields,
# 2. Then for each of two datasets in descriptors dictionary (standard and PCA), we:
#     - Create a pipeline, made of MinMaxScaler and algorithm,
#     - Split dataset into training and testing subsets;
#     - Then we search for optimal parameters with functions from [hyperopt package](http://hyperopt.github.io/hyperopt/);
#     - Then we extract the best model and train it with X_train and y_train;
#     - Then we claculate different metrics (Accuracy, F1-Score, ROC_AUC score) and append it to the special dictionary with results, as well as some information abour descriptors sets and name of studied algorithm
#     - Finally, we plot ROC-AUC curve

# %%
def calculate_to_score(pipe, estimator_name, param_grid, descriptors_dict = descriptors_dict, target=target, type = 'Full'):
    fig, axes = plt.subplots(1, 2, figsize = (12,12))
    i = 0
    for key, value in descriptors_dict.items():
        X_train, X_test, y_train, y_test = train_test_split(value, target, random_state = 0)
        def objective(params, X, target):
            #pipe = make_pipeline(MinMaxScaler(), estimator)
            pipe.set_params(**params)
            
            predictions = cross_val_predict(pipe, X, target, cv = 10)
            score = cross_val_score(pipe, X, target, cv = 10, scoring = 'neg_root_mean_squared_error')
            MAE_CV = mean_absolute_error(predictions, target)
            R2_CV = r2_score(predictions, target)
            
            return {'loss':-score.mean(), 'stddev':score.std(),  'status':STATUS_OK, 'Trained_model':pipe, 'R2_CV':R2_CV, 'MAE_CV':MAE_CV}
            
        trials = Trials()
        best = fmin(partial(objective, X = X_train, target = y_train), space = param_grid, trials = trials, algo = tpe.suggest, max_evals=  5)
        print(best)
        best_model_and_properties = get_best_model_from_trials(trials)

        
        print('Loss is {}'.format(best_model_and_properties[2]))
        print('Standard deviation is {}'.format(best_model_and_properties[1]))
        best_estimator  = best_model_and_properties[0]
        
        scores['RMSE_CV'].append(best_model_and_properties[2])
        scores['Stddev_RMSE_CV'].append(best_model_and_properties[1])
        scores['R2_CV'].append(best_model_and_properties[3])
        scores['MAE_CV'].append(best_model_and_properties[4])
        best_estimator.fit(X_train, y_train)
        predictions = best_estimator.predict(X_test)

        
        scores['RMSE_test'].append(root_mean_squared_error(y_test, predictions))
        scores['MAE_test'].append(mean_absolute_error(y_test, predictions))
        scores['R2_test'].append(r2_score(y_test, predictions))
        scores['Full or PCA'].append(type)
        scores['Estimator'].append(estimator_name)
       
        axes[i].scatter(y_test, predictions)
        #axes[i].plot([0,1],[0,1], 'k--')
        axes[i].set_title('Parity plot for {} descriptors'.format(key))
        axes[i].set_xlabel('Test values')
        axes[i].set_ylabel('Predicted values')
        scores['Descriptors'].append(key)
        i += 1
    plt.tight_layout()

# %% [markdown]
# Subfunction below is to retrieve best model from Trials object ans is used in main functions

# %%
def get_best_model_from_trials(trials):
    valid_trial_list = [trial for trial in trials if trial['result']['status'] == STATUS_OK]
    losses = [ float(trial['result']['loss']) for trial in valid_trial_list]
    index_having_minumum_loss = np.argmin(losses)
    best_trial_obj = valid_trial_list[index_having_minumum_loss]
    return (best_trial_obj['result']['Trained_model'], best_trial_obj['result']['stddev'], best_trial_obj['result']['loss'], 
            best_trial_obj['result']['R2_CV'],  best_trial_obj['result']['MAE_CV'])

# %% [markdown]
# Let's initialize scores dictionary and test function with Logistic Regression

# %%
pipe = Pipeline([('var_sel', VarianceThreshold(threshold=0.1)), ('scaler', StandardScaler()), 
                 ('lasso',Lasso(max_iter=15000))])

# %%
param_grid = {'var_sel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4), 
             'lasso__alpha':hp.loguniform(label = 'alpha', low = -2, high  = 2)}

# %%
calculate_to_score(pipe, estimator_name='Lasso regression', 
                   param_grid = param_grid)
# Out:
# 100%|██████████| 5/5 [00:08<00:00,  1.61s/trial, best loss: 1.6036125257951972]
# {'alpha': 0.26580519123286095, 'threshold': 0.2878686746938109}
# Loss is 1.6036125257951972
# Standard deviation is 0.1446187907026307
# 100%|██████████| 5/5 [00:08<00:00,  1.73s/trial, best loss: 1.6779702503580147]
# {'alpha': 0.4705061294360385, 'threshold': 0.02463488959394038}
# Loss is 1.6779702503580147
# Standard deviation is 0.1483244931770542

# %%
scores
# Out:
# {'Descriptors': [],
#  'Estimator': ['Lasso regression', 'Lasso regression'],
#  'Full or PCA': ['Full', 'Full'],
#  'RMSE_CV': [1.6036125257951972, 1.6779702503580147],
#  'Stddev_RMSE_CV': [0.1446187907026307, 0.1483244931770542],
#  'R2_CV': [-15.977067930653753, -117.88894077235383],
#  'MAE_CV': [1.3076286306595255, 1.3797049132431405],
#  'RMSE_test': [1.4835584123577361, 1.4341671338187056],
#  'MAE_test': [1.2218584591743193, 1.170129072033959],
#  'R2_test': [-0.0024963364173349323, 0.06314360721263812]}

# %%
calculate_to_score(pipe, estimator_name='Lasso Regression', 
                   param_grid = param_grid,
                  descriptors_dict=descriptors_dict_pca, type = 'PCA')
# Out:
# 100%|██████████| 20/20 [00:45<00:00,  2.25s/trial, best loss: 1.5216318704760803]
# {'alpha': 0.14594827372679003, 'threshold': 0.21600067398726594}
# Loss is -1.5216318704760803
# Standard deviation is 0.13653736185798776
# 100%|██████████| 20/20 [00:36<00:00,  1.82s/trial, best loss: 1.5024681977707675]
# {'alpha': 0.16115905700936486, 'threshold': 0.20563027676933637}
# Loss is -1.5024681977707675
# Standard deviation is 0.14222547986628417

# %% [markdown]
# Let's continue with other models. The first one will be
# **Random Forest Classification**

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),('randomforest', RandomForestClassifier(n_jobs = -1))])

# %%
space={'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
    'randomforest__max_depth':hp.randint('max_depth',1,50),  'randomforest__max_features':hp.choice('max_features', [None, 'sqrt', 'log2']),
       'randomforest__min_samples_split':hp.randint('min_samples_split', 2, 8),
       'randomforest__min_samples_leaf': hp.randint('min_samples_leaf', 1, 10),
      'randomforest__n_estimators':hp.randint('n_estimators',50, 500),
      'randomforest__criterion': hp.choice('criterion', ["gini", "entropy", "log_loss"])}

# %%
calculate_to_score(pipe, estimator_name = 'Random Forest', param_grid =  space,
                   descriptors_dict=descriptors_dict,
                   target=target,type = 'Full')
# Out:
# 100%|██████████| 50/50 [09:20<00:00, 11.22s/trial, best loss: -0.8079671491299398]
# {'criterion': 2, 'max_depth': 27, 'max_features': 0, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 142, 'threshold': 0.06946651565326253}
# Loss is 0.8079671491299398
# Standard deviation is 0.0371636860486592
# 100%|██████████| 50/50 [10:06<00:00, 12.13s/trial, best loss: -0.8239128546885915]
# {'criterion': 0, 'max_depth': 48, 'max_features': 0, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 263, 'threshold': 0.2727362555566628}
# Loss is 0.8239128546885915
# Standard deviation is 0.021546161620292964

# %%
calculate_to_score(pipe, estimator_name = 'Random Forest', param_grid =  space,
                   descriptors_dict=descriptors_dict_pca,
                   target=target,                   type = 'PCA')
# Out:
# 100%|██████████| 50/50 [09:31<00:00, 11.44s/trial, best loss: -0.8128590971272229]
# {'criterion': 0, 'max_depth': 10, 'max_features': 0, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 397, 'threshold': 0.39939195456552284}
# Loss is 0.8128590971272229
# Standard deviation is 0.04282832706834364
# 100%|██████████| 50/50 [13:55<00:00, 16.70s/trial, best loss: -0.8350618798860895]
# {'criterion': 1, 'max_depth': 45, 'max_features': 0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 141, 'threshold': 0.35664215895851387}
# Loss is 0.8350618798860895
# Standard deviation is 0.013532167568550435

# %% [markdown]
# **XGBoost**

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),('xgbclassifier', XGBClassifier(n_jobs = -1))])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
        'xgbclassifier__n_estimators':hp.randint('n_estimators', 1, 30),
         'xgbclassifier__learning_rate': hp.loguniform('learning_rate', low = -4*np.log(10), high  = 2*np.log(10)),
         'xgbclassifier__reg_alpha':hp.loguniform(label = 'reg_alpha', low = -4*np.log(10), high  = 2*np.log(10)),
         'xgbclassifier__max_depth':hp.randint('max_depth', 1, 100)}

# %%
calculate_to_score(pipe, estimator_name='Gradient boosting', param_grid = space,
                   descriptors_dict=descriptors_dict,
                   target=target,
                   type = 'Full')
# Out:
#  76%|███████▌  | 38/50 [01:58<00:41,  3.43s/trial, best loss: -0.8193422736683607]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  80%|████████  | 40/50 [02:02<00:26,  2.67s/trial, best loss: -0.8193422736683607]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  88%|████████▊ | 44/50 [02:09<00:13,  2.20s/trial, best loss: -0.8244658359947822]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  90%|█████████ | 45/50 [02:11<00:10,  2.05s/trial, best loss: -0.8244658359947822]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|██████████| 50/50 [02:21<00:00,  2.83s/trial, best loss: -0.8262377754212326]
# {'learning_rate': 1.5411646247659054, 'max_depth': 43, 'n_estimators': 21, 'reg_alpha': 0.008576692805501723, 'threshold': 0.24579944094424266}
# Loss is 0.8262377754212326
# Standard deviation is 0.039052750552711415
#  50%|█████     | 25/50 [01:40<01:59,  4.79s/trial, best loss: -0.8569204097714735]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  56%|█████▌    | 28/50 [01:51<01:39,  4.51s/trial, best loss: -0.8569204097714735]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  68%|██████▊   | 34/50 [02:14<01:00,  3.75s/trial, best loss: -0.8569204097714735]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|██████████| 50/50 [03:04<00:00,  3.70s/trial, best loss: -0.8569204097714735]
# {'learning_rate': 1.0115127678676137, 'max_depth': 65, 'n_estimators': 17, 'reg_alpha': 0.0005231171673864555, 'threshold': 0.026950989747011357}
# Loss is 0.8569204097714735
# Standard deviation is 0.036753248529586266

# %%
calculate_to_score(pipe, estimator_name='Gradient boosting', param_grid = space,
                   descriptors_dict=descriptors_dict_pca,
                   target=target,
                   type = 'PCA')
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  18%|█▊        | 9/50 [00:25<02:02,  2.98s/trial, best loss: -0.81819382825594]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  80%|████████  | 40/50 [01:46<00:26,  2.64s/trial, best loss: -0.821060606060606]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  86%|████████▌ | 43/50 [01:50<00:13,  1.86s/trial, best loss: -0.821060606060606]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  98%|█████████▊| 49/50 [02:05<00:02,  2.60s/trial, best loss: -0.821060606060606]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|██████████| 50/50 [02:07<00:00,  2.55s/trial, best loss: -0.821060606060606]
# {'learning_rate': 0.8567977144950809, 'max_depth': 51, 'n_estimators': 19, 'reg_alpha': 0.008281183250539541, 'threshold': 0.27206173382554916}
# Loss is 0.821060606060606
# Standard deviation is 0.04263516291303168
#   8%|▊         | 4/50 [00:10<01:53,  2.47s/trial, best loss: -0.8041479345361331]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  18%|█▊        | 9/50 [00:23<01:33,  2.29s/trial, best loss: -0.8446607954542961]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  46%|████▌     | 23/50 [01:04<01:44,  3.86s/trial, best loss: -0.8460672384895986]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  64%|██████▍   | 32/50 [01:30<00:45,  2.53s/trial, best loss: -0.8460672384895986]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  70%|███████   | 35/50 [01:41<00:50,  3.39s/trial, best loss: -0.8460672384895986]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  88%|████████▊ | 44/50 [02:08<00:17,  2.89s/trial, best loss: -0.8460672384895986]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  90%|█████████ | 45/50 [02:09<00:12,  2.57s/trial, best loss: -0.8460672384895986]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|██████████| 50/50 [02:20<00:00,  2.81s/trial, best loss: -0.8460672384895986]
# {'learning_rate': 0.4713777901457668, 'max_depth': 20, 'n_estimators': 25, 'reg_alpha': 0.01228842813982967, 'threshold': 0.08083105588239244}
# Loss is 0.8460672384895986
# Standard deviation is 0.03987909950262404

# %% [markdown]
# **SVM**

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('model_sel',SelectFromModel(LogisticRegression(max_iter=10000))),
                 ('svc', SVC(probability=True))])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
         'model_sel__estimator__C':hp.loguniform(label = 'alpha', low = -1, high =2),
    'svc__C':hp.loguniform('C', -3*np.log(10), 2*np.log(10)),
         'svc__kernel':hp.choice('kernel', ['rbf','poly','linear', 'sigmoid']),
         'svc__degree':hp.choice('degree', [2,3, 4]),
         'svc__gamma':hp.choice('gamma', ['scale', 'auto']),
         'svc__coef0':hp.loguniform('coef0', -3*np.log(10), 0*np.log(10))}

# %%
calculate_to_score(pipe, estimator_name = 'SVC', param_grid = space, descriptors_dict=descriptors_dict, target = target, type = 'Full')
# Out:
# 100%|██████████| 50/50 [00:56<00:00,  1.13s/trial, best loss: -0.7513141620284476]
# {'C': 45.40211477283358, 'alpha': 1.8118977678492931, 'coef0': 0.154821459644207, 'degree': 0, 'gamma': 0, 'kernel': 0, 'threshold': 0.06882990335317182}
# Loss is 0.7513141620284476
# Standard deviation is 0.03973606784731581
# 100%|██████████| 50/50 [01:09<00:00,  1.39s/trial, best loss: -0.773976314733039]
# {'C': 96.84204739213506, 'alpha': 6.368802814520109, 'coef0': 0.08313904159258353, 'degree': 0, 'gamma': 0, 'kernel': 0, 'threshold': 0.36975632596686114}
# Loss is 0.773976314733039
# Standard deviation is 0.05493026350807538

# %%
calculate_to_score(pipe, estimator_name = 'SVC', param_grid = space, descriptors_dict=descriptors_dict_pca, target = target, type = 'PCA')
# Out:
# 100%|██████████| 50/50 [00:54<00:00,  1.09s/trial, best loss: -0.7573848511736709]
# {'C': 97.08248150486939, 'alpha': 1.3039609605248714, 'coef0': 0.24250569624563031, 'degree': 0, 'gamma': 0, 'kernel': 1, 'threshold': 0.18241258594507598}
# Loss is 0.7573848511736709
# Standard deviation is 0.02785781916845065
# 100%|██████████| 50/50 [01:12<00:00,  1.45s/trial, best loss: -0.7770086597465161]
# {'C': 98.10786114246858, 'alpha': 1.2868811498575612, 'coef0': 0.03854101579242448, 'degree': 0, 'gamma': 1, 'kernel': 0, 'threshold': 0.3687913026233027}
# Loss is 0.7770086597465161
# Standard deviation is 0.0520428304220846

# %% [markdown]
# **KNearestneighbors**

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('model_sel',SelectFromModel(LogisticRegression(max_iter=10000))),
                 ('kneighborsclassifier', KNeighborsClassifier())])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
         'model_sel__estimator__C':hp.loguniform(label = 'alpha', low = -1, high =2),
    'kneighborsclassifier__n_neighbors':hp.randint('n_neighbors',1, 10),
         'kneighborsclassifier__weights':hp.choice('weights', ['uniform', 'distance']),
         'kneighborsclassifier__metric':hp.choice('metric', ['minkowski', 'chebyshev', 'cosine', 'euclidean'])}

# %%
calculate_to_score(pipe, estimator_name='KMeans', param_grid=space, 
                   descriptors_dict=descriptors_dict, target=target, type = 'Full')
# Out:
# 100%|██████████| 50/50 [00:42<00:00,  1.18trial/s, best loss: -0.7470494417862839]
# {'alpha': 3.0670913059655835, 'metric': 2, 'n_neighbors': 2, 'threshold': 0.25384119773689356, 'weights': 0}
# Loss is 0.7470494417862839
# Standard deviation is 0.046674744013984304
# 100%|██████████| 50/50 [00:47<00:00,  1.04trial/s, best loss: -0.8002018252018251]
# {'alpha': 0.8594202039858693, 'metric': 2, 'n_neighbors': 2, 'threshold': 0.3324349406987568, 'weights': 0}
# Loss is 0.8002018252018251
# Standard deviation is 0.046265296882055655

# %%
calculate_to_score(pipe, estimator_name='KMeans', param_grid=space, 
                   descriptors_dict=descriptors_dict_pca, target=target, type = 'PCA')
# Out:
# 100%|██████████| 50/50 [00:38<00:00,  1.31trial/s, best loss: -0.7717509459924321]
# {'alpha': 0.39039158234638777, 'metric': 2, 'n_neighbors': 2, 'threshold': 0.21264492941396845, 'weights': 0}
# Loss is 0.7717509459924321
# Standard deviation is 0.05153136368178667
# 100%|██████████| 50/50 [00:52<00:00,  1.04s/trial, best loss: -0.8001932538774643]
# {'alpha': 7.324192460834334, 'metric': 2, 'n_neighbors': 2, 'threshold': 0.28060870229875823, 'weights': 0}
# Loss is 0.8001932538774643
# Standard deviation is 0.049442179318697335

# %% [markdown]
# Let's save results into pickle file and show the final scores model in readable format

# %%
with open('score_hyper_opt_all_temp.pickle', 'wb') as output:
    pickle.dump(scores, output)

# %%
pd.DataFrame(scores)
# Out:
#    Descriptors Full or PCA  Presicion_CV  Stddev_CV  Accuracy  F1 - score  \
# 0     Standard        Full      0.739603   0.042615  0.690789    0.715152
# 1        Padel        Full      0.744284   0.032552  0.677632    0.716763
# 2     Standard         PCA      0.742492   0.029869  0.684211    0.710843
# 3        Padel         PCA      0.742667   0.032821  0.697368    0.729412
# 4     Standard        Full      0.807967   0.037164  0.756579    0.773006
# 5        Padel        Full      0.823913   0.021546  0.756579    0.781065
# 6     Standard         PCA      0.812859   0.042828  0.769737    0.790419
# 7        Padel         PCA      0.835062   0.013532  0.690789    0.725146
# 8     Standard        Full      0.826238   0.039053  0.763158    0.780488
# 9        Padel        Full      0.856920   0.036753  0.717105    0.751445
# 10    Standard         PCA      0.821061   0.042635  0.598684    0.573427
# 11       Padel         PCA      0.846067   0.039879  0.532895    0.695279
# 12    Standard        Full      0.751314   0.039736  0.684211    0.720930
# 13       Padel        Full      0.773976   0.054930  0.532895    0.695279
# 14    Standard         PCA      0.757385   0.027858  0.717105    0.748538
# 15       Padel         PCA      0.777009   0.052043  0.684211    0.717647
# 16    Standard        Full      0.747049   0.046675  0.710526    0.690141
# 17       Padel        Full      0.800202   0.046265  0.717105    0.742515
# 18    Standard         PCA      0.771751   0.051531  0.697368    0.735632
# 19       Padel         PCA      0.800193   0.049442  0.763158    0.753425
#
#     ROC-AUC Score            Estimator  Recall score  Precision score
# 0        0.745783  Logistic Regression      0.728395         0.702381
# 1        0.761781  Logistic Regression      0.765432         0.673913
# 2        0.699183  Logistic Regression      0.728395         0.694118
# 3        0.760389  Logistic Regression      0.765432         0.696629
# 4        0.850982        Random Forest      0.777778         0.768293
# 5        0.841593        Random Forest      0.814815         0.750000
# 6        0.867154        Random Forest      0.814815         0.767442
# 7        0.801947        Random Forest      0.765432         0.688889
# 8        0.826030    Gradient boosting      0.790123         0.771084
# 9        0.797774    Gradient boosting      0.802469         0.706522
# 10       0.660929    Gradient boosting      0.506173         0.661290
# 11       0.782212    Gradient boosting      1.000000         0.532895
# 12       0.796731                  SVC      0.765432         0.681319
# 13       0.741610                  SVC      1.000000         0.532895
# 14       0.798644                  SVC      0.790123         0.711111
# 15       0.767519                  SVC      0.753086         0.685393
# 16       0.759955               KMeans      0.604938         0.803279
# 17       0.803947               KMeans      0.765432         0.720930
# 18       0.794905               KMeans      0.790123         0.688172
# 19       0.794471               KMeans      0.679012         0.846154

# %% [markdown]
# As we can see, simple KMeans model with Padel regressors with following parameters:
# **{'metric': 2, 'n_neighbors': 2, 'weights': 0}**
# Shows the best performance in terms of precision and can be applied further to predict if the system is geleous under studied conditions
