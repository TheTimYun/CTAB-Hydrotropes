# %% [markdown]
# **Overview**
# This notebook describes folloiwing stages:
# 1. Creating functions to:
#     - perform search for optimal algorithm parameters;
#     - train model;
#     - evaluate the model on the test set;
#     - plot ROC-AUC curve
# 2. Evaluate following algorithms for the classification task using structure-based splitting strategy:
#     - Logistic regression;
#     - Random Forest;
#     - Gradient Boosting as implemented in XGBoost;
#     - Support Vector Machines;
#     - K-Nearest Neighborrs
# 3. Creare dataframe with evaluation results

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, StratifiedGroupKFold, GridSearchCV, GroupShuffleSplit, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score, precision_score, roc_curve, recall_score
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# First, let's import datasets and y-target, created earlier:

# %%
with open('X_padel.pickle', 'rb') as input:
    X_padel = pickle.load(input)

# %%
with open('X_standard.pickle', 'rb') as input:
    X_standard = pickle.load(input)

# %%
with open('y.pickle', 'rb') as input:
    target = pickle.load(input)

# %% [markdown]
# To carry out structure-based split we import *groups.pickle*, which contains information about the nature of chemical additives. Each unique SMILES is encoded into a number, which is ascrbed to every datapoint in the dataset. Splitting is then made on the base of this number

# %%
with open('groups.pickle', 'rb') as input:
    groups = pickle.load(input)

# %% [markdown]
# To facilitate automatic calculation of metrics and asiggning labels, we weill create dictionaries with imported descriptors datasets (Stadard and PaDEL)

# %%
descriptors_dict = {'Standard':X_standard, 'Padel':X_padel}

# %% [markdown]
# Here we instantiate scores dictionary that will contain metrics obtained during cross-validation and test set evaluation

# %%
scores = {'Descriptors':[], 'Full or PCA':[], 'Presicion_CV':[], 'Stddev_CV':[], 'Accuracy':[], 'F1 - score':[], 'ROC-AUC Score':[], 'Estimator':[], 'Recall score':[], 'Precision score':[]}

# %% [markdown]
# The function below performs multiple tasks:
# 1. First, it create matplotlib figure object and axes with two fields,
# 2. Then for each of two datasets in descriptors dictionary (RDKit and PaDEL), we:
#     - Split dataset into training and testing subsets in a structure-based manner;
#     - Instantiate a pipeline with parameters provided by HyperOpt;
#     - Search for optimal parameters that yield minimum negatvie mean CV precision using [hyperopt package](http://hyperopt.github.io/hyperopt/). Search os made over 50 iterations;
#     - Extract the best hyperparameters and train model on X_train and y_train;
#     - Calculate different metrics (Precision, Accuracy, F1-Score, ROC_AUC score) on the test set and append them to the "Scores" dictionary, as well as some information abour descriptors sets and name of studied algorithm
#     - Finally, we plot ROC-AUC curves and save them to folder

# %%
def calculate_to_score(pipe, estimator_name, param_grid, descriptors_dict = descriptors_dict, target=target, type = 'Full', groups = groups):
    fig, axes = plt.subplots(1, 2, figsize = (26,12))
    i = 0
    for key, value in descriptors_dict.items():
        splitter = GroupShuffleSplit(n_splits=2, random_state = 0)
        #Group Shuffle Split is used for structure-based splitting
        split = splitter.split(X = value, y = target, groups = groups)
        train_indices, test_indices = next(split)
        X_train, y_train, groups_train = value.iloc[train_indices], target.iloc[train_indices], groups[train_indices]
        X_test, y_test, groups_test = value.iloc[test_indices], target.iloc[test_indices], groups[test_indices]       
        #structure-based split during CV
        cv = StratifiedGroupKFold(n_splits = 10)
        def objective(params, X, target, groups_train):
            #pipe = make_pipeline(MinMaxScaler(), estimator)
            pipe.set_params(**params)
            score = cross_val_score(pipe, X, target, cv = cv, groups = groups_train, scoring = 'precision')
            
            return {'loss':-score.mean(), 'stddev':score.std(),  'status':STATUS_OK, 'Trained_model':pipe}
        trials = Trials()
        best = fmin(partial(objective, X = X_train, target = y_train, groups_train = groups_train), space = param_grid, trials = trials, algo = tpe.suggest, max_evals=  50)
        print(best)
        best_model_and_properties = get_best_model_from_trials(trials)

        
        print('Loss is {}'.format(best_model_and_properties[2]))
        print('Standard deviation is {}'.format(best_model_and_properties[1]))
        best_estimator  = best_model_and_properties[0]
        scores['Presicion_CV'].append(best_model_and_properties[2])
        scores['Stddev_CV'].append(best_model_and_properties[1])


        
        best_estimator.fit(X_train, y_train)
        predictions = best_estimator.predict(X_test)
        probs = best_estimator.predict_proba(X_test)[:,1]
        scores['Descriptors'].append(key)
        scores['Accuracy'].append(accuracy_score(y_test, predictions))
        scores['F1 - score'].append(f1_score(y_test, predictions))
        scores['ROC-AUC Score'].append(roc_auc_score(y_test, probs))
        scores['Recall score'].append(recall_score(y_test, predictions))
        scores['Precision score'].append(precision_score(y_test, predictions))
        scores['Full or PCA'].append(type)
        scores['Estimator'].append(estimator_name)
        fpr, tpr, _ = roc_curve(y_test, probs)
        axes[i].plot(fpr, tpr)
        axes[i].plot([0,1],[0,1], 'k--')
        axes[i].set_title('ROC-AUC Curve for {} descriptors'.format(key))
        axes[i].set_xlabel('False positive rate')
        axes[i].set_ylabel('True positive rate')
        i += 1
    plt.tight_layout()
    plt.savefig('ROC_AUC_all_temps_structure_based/'+estimator_name+'_'+type+'.png')

# %% [markdown]
# Subfunction below is made to retrieve best model from Trials object ans is used in main functions

# %%
def get_best_model_from_trials(trials):
    valid_trial_list = [trial for trial in trials if trial['result']['status'] == STATUS_OK]
    losses = [ float(trial['result']['loss']) for trial in valid_trial_list]
    index_having_minumum_loss = np.argmin(losses)
    best_trial_obj = valid_trial_list[index_having_minumum_loss]
    return best_trial_obj['result']['Trained_model'], best_trial_obj['result']['stddev'], -best_trial_obj['result']['loss']

# %% [markdown]
# We start with logistic regression

# %%
pipe = Pipeline([('var_sel', VarianceThreshold(threshold=0.1)), ('scaler', StandardScaler()), 
                 ('logisticregression',LogisticRegression(max_iter=10000))])

# %%
param_grid = {'var_sel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4), 
             'logisticregression__C':hp.loguniform(label = 'C', low = -4*np.log(10), high  = 2*np.log(10))}

# %%
calculate_to_score(pipe, estimator_name='Logistic Regression', 
                   param_grid = param_grid)
# Out:
# 100%|███████████████████████████████████████████████| 50/50 [01:19<00:00,  1.59s/trial, best loss: -0.7255715737497545]
# {'C': 0.009370017203785075, 'threshold': 0.0737016823259483}
# Loss is 0.7255715737497545
# Standard deviation is 0.12088259935420734
# 100%|███████████████████████████████████████████████| 50/50 [01:30<00:00,  1.80s/trial, best loss: -0.7183817646317647]
# {'C': 0.022327540110811752, 'threshold': 0.1561625966467177}
# Loss is 0.7183817646317647
# Standard deviation is 0.1411335013080172

# %% [markdown]
# In this stage we insert PCA into a pipeline to check if the dimensionality reduction can improve predictive performance

# %%
pipe = Pipeline([('var_sel', VarianceThreshold(threshold=0.1)), ('scaler', StandardScaler()), ('PCA', PCA(n_components = 50)), 
                 ('logisticregression',LogisticRegression(max_iter=10000))])

calculate_to_score(pipe, estimator_name='Logistic Regression', 
                   param_grid = param_grid, type = 'PCA')
# Out:
# 100%|███████████████████████████████████████████████| 50/50 [01:15<00:00,  1.51s/trial, best loss: -0.7282184790180557]
# {'C': 0.021007557857005678, 'threshold': 0.003518168339481431}
# Loss is 0.7282184790180557
# Standard deviation is 0.09696005720049329
# 100%|███████████████████████████████████████████████| 50/50 [01:15<00:00,  1.51s/trial, best loss: -0.7185052242558551]
# {'C': 0.02067544290279628, 'threshold': 0.3992038234139556}
# Loss is 0.7185052242558551
# Standard deviation is 0.14332198145368769

# %% [markdown]
# Let's continue with other algorithms. The first one will be
# **Random Forest Classification**

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),('randomforest', RandomForestClassifier(n_jobs = -1))])

# %%
space={'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
    'randomforest__max_depth':hp.randint('max_depth',1,50),  'randomforest__max_features':hp.choice('max_features', [None, 'sqrt', 'log2']),
       'randomforest__min_samples_split':hp.randint('min_samples_split', 2, 8),
       'randomforest__min_samples_leaf': hp.randint('min_samples_leaf', 1, 10),
      'randomforest__n_estimators':hp.randint('n_estimators',50, 500),
      'randomforest__criterion': hp.choice('criterion', ["gini", "entropy", "log_loss"])}

# %%
calculate_to_score(pipe, estimator_name = 'Random Forest', param_grid =  space,
                   descriptors_dict=descriptors_dict,
                   target=target,type = 'Full')
# Out:
# 100%|███████████████████████████████████████████████| 50/50 [20:20<00:00, 24.42s/trial, best loss: -0.7897570314675578]
# {'criterion': 0, 'max_depth': 20, 'max_features': 0, 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 383, 'threshold': 0.2402097332554433}
# Loss is 0.7897570314675578
# Standard deviation is 0.10834141036315141
# 100%|████████████████████████████████████████████████| 50/50 [27:53<00:00, 33.47s/trial, best loss: -0.772746810355506]
# {'criterion': 2, 'max_depth': 34, 'max_features': 0, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 106, 'threshold': 0.2664331073401344}
# Loss is 0.772746810355506
# Standard deviation is 0.11514724278138033

# %%
n = 2

# %%
for key in scores.keys():
    del scores[key][-n:]

# %%
pipe = Pipeline([('varsel', VarianceThreshold()), ('scaler', StandardScaler()), ('PCA', PCA(n_components = 50)),('randomforest', RandomForestClassifier(n_jobs = -1))])

calculate_to_score(pipe, estimator_name = 'Random Forest', param_grid =  space,
                   target=target,                   type = 'PCA')
# Out:
# 100%|███████████████████████████████████████████████| 50/50 [06:32<00:00,  7.85s/trial, best loss: -0.7157857744213579]
# {'criterion': 0, 'max_depth': 22, 'max_features': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 434, 'threshold': 0.12370992552916167}
# Loss is 0.7157857744213579
# Standard deviation is 0.12794803897057572
#  50%|███████████████████████▌                       | 25/50 [03:31<02:30,  6.01s/trial, best loss: -0.7798288058856819]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  52%|████████████████████████▍                      | 26/50 [03:38<02:33,  6.38s/trial, best loss: -0.7798288058856819]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|███████████████████████████████████████████████| 50/50 [06:51<00:00,  8.22s/trial, best loss: -0.7798288058856819]
# {'criterion': 2, 'max_depth': 47, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 248, 'threshold': 0.12944255848305866}
# Loss is 0.7798288058856819
# Standard deviation is 0.1456735578538547

# %% [markdown]
# **XGBoost**

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),('xgbclassifier', XGBClassifier(n_jobs = -1))])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
        'xgbclassifier__n_estimators':hp.randint('n_estimators', 1, 30),
         'xgbclassifier__learning_rate': hp.loguniform('learning_rate', low = -4*np.log(10), high  = 2*np.log(10)),
         'xgbclassifier__reg_alpha':hp.loguniform(label = 'reg_alpha', low = -4*np.log(10), high  = 2*np.log(10)),
         'xgbclassifier__max_depth':hp.randint('max_depth', 1, 100)}

# %%
calculate_to_score(pipe, estimator_name='Gradient boosting', param_grid = space,
                   descriptors_dict=descriptors_dict,
                   target=target,
                   type = 'Full')
# Out:
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  34%|███████████████▉                               | 17/50 [01:22<04:08,  7.53s/trial, best loss: -0.7662560513531875]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  68%|███████████████████████████████▉               | 34/50 [03:02<01:19,  4.99s/trial, best loss: -0.7852637975480047]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  88%|█████████████████████████████████████████▎     | 44/50 [03:58<00:34,  5.68s/trial, best loss: -0.7852637975480047]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|███████████████████████████████████████████████| 50/50 [04:32<00:00,  5.46s/trial, best loss: -0.7852637975480047]
# {'learning_rate': 0.474671706689742, 'max_depth': 32, 'n_estimators': 20, 'reg_alpha': 0.00021430267549132703, 'threshold': 0.292922165900688}
# Loss is 0.7852637975480047
# Standard deviation is 0.0791666794135826
#  38%|█████████████████▊                             | 19/50 [01:52<03:21,  6.50s/trial, best loss: -0.7843241611329848]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  52%|████████████████████████▍                      | 26/50 [02:44<02:29,  6.23s/trial, best loss: -0.7843241611329848]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  60%|████████████████████████████▏                  | 30/50 [03:12<02:21,  7.05s/trial, best loss: -0.7843241611329848]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  64%|██████████████████████████████                 | 32/50 [03:22<01:49,  6.11s/trial, best loss: -0.7843241611329848]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  74%|██████████████████████████████████▊            | 37/50 [03:41<00:55,  4.24s/trial, best loss: -0.7843241611329848]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  80%|█████████████████████████████████████▌         | 40/50 [03:57<00:55,  5.57s/trial, best loss: -0.7843241611329848]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|███████████████████████████████████████████████| 50/50 [04:52<00:00,  5.85s/trial, best loss: -0.7843241611329848]
# {'learning_rate': 1.7552472995924364, 'max_depth': 40, 'n_estimators': 28, 'reg_alpha': 0.00017648136257089747, 'threshold': 0.08652422728335574}
# Loss is 0.7843241611329848
# Standard deviation is 0.1518642209493442

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),  ('scaler', StandardScaler()), ('PCA', PCA(n_components = 50)),('xgbclassifier', XGBClassifier(n_jobs = -1))])

calculate_to_score(pipe, estimator_name='Gradient boosting', param_grid = space,
                   target=target,
                   type = 'PCA')
# Out:
#  12%|█████▊                                          | 6/50 [00:13<01:31,  2.09s/trial, best loss: -0.6073600300070889]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  30%|██████████████                                 | 15/50 [00:43<01:50,  3.14s/trial, best loss: -0.6304330631242395]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  40%|██████████████████▊                            | 20/50 [00:56<01:23,  2.78s/trial, best loss: -0.6304330631242395]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  42%|███████████████████▋                           | 21/50 [00:59<01:18,  2.69s/trial, best loss: -0.6304330631242395]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  44%|████████████████████▋                          | 22/50 [01:01<01:11,  2.55s/trial, best loss: -0.6304330631242395]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  54%|█████████████████████████▍                     | 27/50 [01:15<00:59,  2.57s/trial, best loss: -0.6361190511433646]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  58%|███████████████████████████▎                   | 29/50 [01:22<01:04,  3.05s/trial, best loss: -0.6361190511433646]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  64%|██████████████████████████████                 | 32/50 [01:29<00:49,  2.73s/trial, best loss: -0.6361190511433646]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  84%|███████████████████████████████████████▍       | 42/50 [02:05<00:29,  3.65s/trial, best loss: -0.6393904708893268]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  86%|████████████████████████████████████████▍      | 43/50 [02:08<00:23,  3.29s/trial, best loss: -0.6393904708893268]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  92%|███████████████████████████████████████████▏   | 46/50 [02:17<00:12,  3.21s/trial, best loss: -0.6393904708893268]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|███████████████████████████████████████████████| 50/50 [02:29<00:00,  2.99s/trial, best loss: -0.6711328724235072]
# {'learning_rate': 0.7641936676973318, 'max_depth': 82, 'n_estimators': 10, 'reg_alpha': 0.21099042119385472, 'threshold': 0.09590777549908949}
# Loss is 0.6711328724235072
# Standard deviation is 0.12226172505070847
#  16%|███████▊                                         | 8/50 [00:20<01:51,  2.64s/trial, best loss: -0.584817821067821]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  18%|████████▊                                        | 9/50 [00:22<01:43,  2.54s/trial, best loss: -0.584817821067821]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  20%|█████████▌                                      | 10/50 [00:24<01:38,  2.45s/trial, best loss: -0.584817821067821]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  72%|█████████████████████████████████▊             | 36/50 [01:53<00:41,  2.96s/trial, best loss: -0.6323492620748719]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  92%|███████████████████████████████████████████▏   | 46/50 [02:23<00:11,  2.75s/trial, best loss: -0.6705653043266473]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|███████████████████████████████████████████████| 50/50 [02:32<00:00,  3.05s/trial, best loss: -0.6705653043266473]
# {'learning_rate': 0.39236933543256025, 'max_depth': 53, 'n_estimators': 24, 'reg_alpha': 1.7103613469965706, 'threshold': 0.2443199479889544}
# Loss is 0.6705653043266473
# Standard deviation is 0.18061973400592585

# %% [markdown]
# **SVM**

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('model_sel',SelectFromModel(LogisticRegression(max_iter=10000))),
                 ('svc', SVC(probability=True))])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
         'model_sel__estimator__C':hp.loguniform(label = 'alpha', low = -1, high =2),
    'svc__C':hp.loguniform('C', -3*np.log(10), 1*np.log(10)),
         'svc__kernel':hp.choice('kernel', ['rbf','poly','linear', 'sigmoid']),
         'svc__degree':hp.choice('degree', [2,3]),
         'svc__gamma':hp.choice('gamma', ['scale', 'auto']),
         'svc__coef0':hp.loguniform('coef0', -3*np.log(10), 0*np.log(10))}

# %%
calculate_to_score(pipe, estimator_name = 'SVC', param_grid = space, descriptors_dict=descriptors_dict, target = target, type = 'Full')
# Out:
#   4%|█▉                                               | 2/50 [00:04<01:46,  2.23s/trial, best loss: -0.739176632191338]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#   6%|██▉                                              | 3/50 [00:06<01:43,  2.19s/trial, best loss: -0.739176632191338]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  40%|███████████████████▏                            | 20/50 [00:52<01:21,  2.70s/trial, best loss: -0.739176632191338]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  54%|█████████████████████████▍                     | 27/50 [01:08<00:54,  2.37s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  56%|██████████████████████████▎                    | 28/50 [01:10<00:49,  2.26s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  58%|███████████████████████████▎                   | 29/50 [01:12<00:46,  2.21s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  60%|████████████████████████████▏                  | 30/50 [01:15<00:45,  2.29s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  62%|█████████████████████████████▏                 | 31/50 [01:17<00:45,  2.40s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  64%|██████████████████████████████                 | 32/50 [01:20<00:42,  2.33s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  68%|███████████████████████████████▉               | 34/50 [01:24<00:36,  2.27s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  90%|██████████████████████████████████████████▎    | 45/50 [01:52<00:13,  2.63s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  92%|███████████████████████████████████████████▏   | 46/50 [01:54<00:10,  2.54s/trial, best loss: -0.7978769841269842]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|███████████████████████████████████████████████| 50/50 [02:07<00:00,  2.54s/trial, best loss: -0.7978769841269842]
# {'C': 0.5725036554821588, 'alpha': 0.38668050511309904, 'coef0': 0.0012521822997244667, 'degree': 1, 'gamma': 1, 'kernel': 1, 'threshold': 0.2421650750612668}
# Loss is 0.7978769841269842
# Standard deviation is 0.16345483399701485
# 100%|███████████████████████████████████████████████| 50/50 [03:07<00:00,  3.75s/trial, best loss: -0.6819817694488747]
# {'C': 0.07934432079478003, 'alpha': 0.40449690404767746, 'coef0': 0.013019348790457377, 'degree': 1, 'gamma': 1, 'kernel': 2, 'threshold': 0.08633399217285286}
# Loss is 0.6819817694488747
# Standard deviation is 0.11239053831812197

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('PCA', PCA(n_components = 50)),
                 ('model_sel',SelectFromModel(LogisticRegression(max_iter=10000))),
                 ('svc', SVC(probability=True))])

calculate_to_score(pipe, estimator_name = 'SVC', param_grid = space, target = target, type = 'PCA')
# Out:
#  46%|█████████████████████▌                         | 23/50 [00:57<01:08,  2.52s/trial, best loss: -0.6511433625442247]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 100%|███████████████████████████████████████████████| 50/50 [02:28<00:00,  2.98s/trial, best loss: -0.7042857208117506]
# {'C': 0.4222400963768823, 'alpha': 3.130931709034691, 'coef0': 0.07169039342057174, 'degree': 1, 'gamma': 0, 'kernel': 2, 'threshold': 0.020802007092885114}
# Loss is 0.7042857208117506
# Standard deviation is 0.11516625210517656
# 100%|███████████████████████████████████████████████| 50/50 [02:26<00:00,  2.93s/trial, best loss: -0.7153513760634505]
# {'C': 1.1793268066575244, 'alpha': 3.214849532349395, 'coef0': 0.18147687241808522, 'degree': 0, 'gamma': 1, 'kernel': 0, 'threshold': 0.2809781565539229}
# Loss is 0.7153513760634505
# Standard deviation is 0.1183956362813595

# %% [markdown]
# **KNearestneighbors**

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('model_sel',SelectFromModel(LogisticRegression(max_iter=10000))),
                 ('kneighborsclassifier', KNeighborsClassifier())])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
         'model_sel__estimator__C':hp.loguniform(label = 'alpha', low = -1, high =2),
    'kneighborsclassifier__n_neighbors':hp.randint('n_neighbors',1, 10),
         'kneighborsclassifier__weights':hp.choice('weights', ['uniform', 'distance']),
         'kneighborsclassifier__metric':hp.choice('metric', ['minkowski', 'chebyshev', 'cosine', 'euclidean'])}

# %%
calculate_to_score(pipe, estimator_name='KMeans', param_grid=space, 
                   descriptors_dict=descriptors_dict, target=target, type = 'Full')
# Out:
# 100%|███████████████████████████████████████████████| 50/50 [01:53<00:00,  2.28s/trial, best loss: -0.7292388167388169]
# {'alpha': 0.6411410485136023, 'metric': 2, 'n_neighbors': 2, 'threshold': 0.2127012933871293, 'weights': 0}
# Loss is 0.7292388167388169
# Standard deviation is 0.11775024320061867
# 100%|███████████████████████████████████████████████| 50/50 [02:15<00:00,  2.71s/trial, best loss: -0.7129034280936455]
# {'alpha': 2.1973180931090077, 'metric': 3, 'n_neighbors': 2, 'threshold': 0.3816693857167236, 'weights': 0}
# Loss is 0.7129034280936455
# Standard deviation is 0.11643529154071582

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('PCA', PCA(n_components = 50)),
                 ('model_sel',SelectFromModel(LogisticRegression(max_iter=10000))),
                 ('kneighborsclassifier', KNeighborsClassifier())])

calculate_to_score(pipe, estimator_name='KMeans', param_grid=space, target=target, type = 'PCA')
# Out:
# 100%|███████████████████████████████████████████████| 50/50 [01:28<00:00,  1.77s/trial, best loss: -0.7024019091666152]
# {'alpha': 1.1845731555493526, 'metric': 2, 'n_neighbors': 8, 'threshold': 0.2393808658069817, 'weights': 0}
# Loss is 0.7024019091666152
# Standard deviation is 0.12932051204222514
# 100%|███████████████████████████████████████████████| 50/50 [01:33<00:00,  1.86s/trial, best loss: -0.6765194081281038]
# {'alpha': 4.2522832812972045, 'metric': 2, 'n_neighbors': 7, 'threshold': 0.2481708888265621, 'weights': 1}
# Loss is 0.6765194081281038
# Standard deviation is 0.15361458173708523

# %% [markdown]
# Let's save results into pickle file and show the final scores model in readable format

# %%
pd.DataFrame(scores)
# Out:
#    Descriptors Full or PCA  Presicion_CV  Stddev_CV  Accuracy  F1 - score  \
# 0     Standard        Full      0.725572   0.120883  0.673267    0.707965
# 1        Padel        Full      0.718382   0.141134  0.633663    0.713178
# 2     Standard         PCA      0.728218   0.096960  0.722772    0.745455
# 3        Padel         PCA      0.718505   0.143322  0.732673    0.742857
# 4     Standard        Full      0.789757   0.108341  0.742574    0.754717
# 5        Padel        Full      0.772747   0.115147  0.782178    0.813559
# 6     Standard         PCA      0.715786   0.127948  0.643564    0.632653
# 7        Padel         PCA      0.779829   0.145674  0.762376    0.789474
# 8     Standard        Full      0.785264   0.079167  0.594059    0.677165
# 9        Padel        Full      0.784324   0.151864  0.584158    0.596154
# 10    Standard         PCA      0.671133   0.122262  0.584158    0.611111
# 11       Padel         PCA      0.670565   0.180620  0.564356    0.706667
# 12    Standard        Full      0.797877   0.163455  0.663366    0.742424
# 13       Padel        Full      0.681982   0.112391  0.752475    0.789916
# 14    Standard         PCA      0.704286   0.115166  0.524752    0.529412
# 15       Padel         PCA      0.715351   0.118396  0.603960    0.753086
# 16    Standard        Full      0.729239   0.117750  0.524752    0.428571
# 17       Padel        Full      0.712903   0.116435  0.792079    0.839695
# 18    Standard         PCA      0.702402   0.129321  0.504950    0.444444
# 19       Padel         PCA      0.676519   0.153615  0.633663    0.694215
#
#     ROC-AUC Score            Estimator  Recall score  Precision score
# 0        0.784426  Logistic Regression      0.655738         0.769231
# 1        0.609426  Logistic Regression      0.754098         0.676471
# 2        0.770902  Logistic Regression      0.672131         0.836735
# 3        0.824590  Logistic Regression      0.639344         0.886364
# 4        0.866393        Random Forest      0.655738         0.888889
# 5        0.864139        Random Forest      0.786885         0.842105
# 6        0.762705        Random Forest      0.508197         0.837838
# 7        0.829098        Random Forest      0.737705         0.849057
# 8        0.649385    Gradient boosting      0.704918         0.651515
# 9        0.729918    Gradient boosting      0.508197         0.720930
# 10       0.600410    Gradient boosting      0.540984         0.702128
# 11       0.509221    Gradient boosting      0.868852         0.595506
# 12       0.601230                  SVC      0.803279         0.690141
# 13       0.801230                  SVC      0.770492         0.810345
# 14       0.516393                  SVC      0.442623         0.658537
# 15       0.354508                  SVC      1.000000         0.603960
# 16       0.601434               KMeans      0.295082         0.782609
# 17       0.843648               KMeans      0.901639         0.785714
# 18       0.562295               KMeans      0.327869         0.689655
# 19       0.725410               KMeans      0.688525         0.700000

# %%
with open('score_clf_structure_all_temp.pickle', 'wb') as output:
    pickle.dump(scores, output)
