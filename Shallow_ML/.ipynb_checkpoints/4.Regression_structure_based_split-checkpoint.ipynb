# %% [markdown]
# **Overview**
# This notebook describes folloiwing stages:
# 1. Creating functions to:
#     - perform search for optimal algorithm parameters;
#     - train model;
#     - calculate the most important metrics;
#     - plot ROC-AUC curve
# 2. Assess the results of following algorithms:
#     - Logistic regression;
#     - Random Forest;
#     - Gradient Boosting as implemented in XGBoost;
#     - Support Vector Machines;
#     - K-Nearest Neighborrs
# 3. Creare dataframe with the main indiators of models' performance

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_val_predict, cross_validate
from sklearn.linear_model import Lasso
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score, precision_score, roc_curve, recall_score
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from hyperopt import tpe, Trials, hp, fmin, STATUS_OK
from functools import partial
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# First, let's import datasets and y-target, created earlier:

# %%
with open('X_padel.pickle', 'rb') as input:
    X_padel = pickle.load(input)

# %%
with open('X_standard.pickle', 'rb') as input:
    X_standard = pickle.load(input)

# %%
with open('viscosity.pickle', 'rb') as input:
    target = pickle.load(input)
target = np.log10(target)

# %%
with open('X_standard.pickle', 'rb') as input:
    X_standard_pca = pickle.load(input)

# %%
with open('X_padel.pickle', 'rb') as input:
    X_padel_pca = pickle.load(input)

# %% [markdown]
# To facilitate automatic calculation of metrics and asiggning labels, we weill create dictionaries with imported descriptors datasets (standard datasets and datasetes with reduced dimensionality)

# %%
descriptors_dict = {'Standard':X_standard, 'Padel':X_padel}

# %%
descriptors_dict_pca = {'Standard':X_standard, 'Padel':X_padel}

# %%
scores = {'Descriptors':[], 'Estimator':[], 'Full or PCA':[], 'RMSE_CV':[], 'Stddev_RMSE_CV':[], 'R2_CV':[], 'MAE_CV':[],  'RMSE_test':[], 'MAE_test':[], 'R2_test':[] }

# %% [markdown]
# The function below performs multiple tasks:
# 1. First, it create matplotlib figure object and axes with two fields,
# 2. Then for each of two datasets in descriptors dictionary (standard and PCA), we:
#     - Create a pipeline, made of MinMaxScaler and algorithm,
#     - Split dataset into training and testing subsets;
#     - Then we search for optimal parameters with functions from [hyperopt package](http://hyperopt.github.io/hyperopt/);
#     - Then we extract the best model and train it with X_train and y_train;
#     - Then we claculate different metrics (Accuracy, F1-Score, ROC_AUC score) and append it to the special dictionary with results, as well as some information abour descriptors sets and name of studied algorithm
#     - Finally, we plot ROC-AUC curve

# %%
def calculate_to_score(pipe, estimator_name, param_grid, descriptors_dict = descriptors_dict, target=target, type = 'Full'):
    fig, axes = plt.subplots(1, 2, figsize = (26,12))
    i = 0
    
    scoring = {
    'rmse': 'neg_root_mean_squared_error',
    'mae': 'neg_mean_absolute_error',
    'r2': 'r2'
}
    for key, value in descriptors_dict.items():
        X_train, X_test, y_train, y_test = train_test_split(value, target, random_state = 0)
        def objective(params, X, target):
            #pipe = make_pipeline(MinMaxScaler(), estimator)
            pipe.set_params(**params)
            scores = cross_validate(pipe, X, target, cv = 10, scoring = scoring)
            rmse_cv = -scores['test_rmse'].mean()
            stddev_cv = rmse_cv.std()
            mae_cv = -scores['test_mae'].mean()
            r2_cv = scores['test_r2']
            
            return {'loss':rmse_cv, 'stddev':stddev_cv,  'status':STATUS_OK, 'Trained_model':pipe, 'R2_CV':r2_cv, 'MAE_CV':mae_cv}
            
        trials = Trials()
        best = fmin(partial(objective, X = X_train, target = y_train), space = param_grid, trials = trials, algo = tpe.suggest, max_evals=  50)
        print(best)
        best_model_and_properties = get_best_model_from_trials(trials)

        
        print('Loss is {}'.format(best_model_and_properties[2]))
        print('Standard deviation is {}'.format(best_model_and_properties[1]))
        best_estimator  = best_model_and_properties[0]
        
        scores['RMSE_CV'].append(best_model_and_properties[2])
        scores['Stddev_RMSE_CV'].append(best_model_and_properties[1])
        scores['R2_CV'].append(best_model_and_properties[3])
        scores['MAE_CV'].append(best_model_and_properties[4])
        best_estimator.fit(X_train, y_train)
        predictions = best_estimator.predict(X_test)

        
        scores['RMSE_test'].append(root_mean_squared_error(y_test, predictions))
        scores['MAE_test'].append(mean_absolute_error(y_test, predictions))
        scores['R2_test'].append(r2_score(y_test, predictions))
        scores['Full or PCA'].append(type)
        scores['Estimator'].append(estimator_name)
       
        axes[i].scatter(y_test, predictions)
        axes[i].set_xlim(np.min(y_test), np.max(y_test))
        axes[i].set_ylim(np.min(y_test), np.max(y_test))
        axes[i].plot([np.min(y_test),np.max(y_test)],[np.min(y_test),np.max(y_test)], 'k--')
        axes[i].set_title('Parity plot for {} descriptors'.format(key))
        axes[i].set_xlabel('Test values')
        axes[i].set_ylabel('Predicted values')
        scores['Descriptors'].append(key)
        i += 1
    plt.tight_layout()
    plt.savefig('Parity_plots_random/'+estimator_name+'_'+type+'.png')

# %% [markdown]
# Subfunction below is to retrieve best model from Trials object ans is used in main functions

# %%
def get_best_model_from_trials(trials):
    valid_trial_list = [trial for trial in trials if trial['result']['status'] == STATUS_OK]
    losses = [ float(trial['result']['loss']) for trial in valid_trial_list]
    index_having_minumum_loss = np.argmin(losses)
    best_trial_obj = valid_trial_list[index_having_minumum_loss]
    return (best_trial_obj['result']['Trained_model'], best_trial_obj['result']['stddev'], best_trial_obj['result']['loss'], 
            best_trial_obj['result']['R2_CV'],  best_trial_obj['result']['MAE_CV'])

# %% [markdown]
# Let's initialize scores dictionary and test function with Logistic Regression

# %%
pipe = Pipeline([('var_sel', VarianceThreshold(threshold=0.1)), ('scaler', StandardScaler()), 
                 ('lasso',Lasso(max_iter=15000))])

# %%
param_grid = {'var_sel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4), 
             'lasso__alpha':hp.loguniform(label = 'alpha', low = -2, high  = 2)}

# %%
calculate_to_score(pipe, estimator_name='Lasso regression', 
                   param_grid = param_grid)
# Out:
# 100%|██████████| 50/50 [00:57<00:00,  1.14s/trial, best loss: 1.499773371148896]
# {'alpha': 0.1378893124144692, 'threshold': 0.021139435841438448}
# Loss is 1.499773371148896
# Standard deviation is 0.0
# 100%|██████████| 50/50 [00:54<00:00,  1.09s/trial, best loss: 1.492038475326574]
# {'alpha': 0.15570360313712248, 'threshold': 0.08914226493773031}
# Loss is 1.492038475326574
# Standard deviation is 0.0

# %%
calculate_to_score(pipe, estimator_name='Lasso Regression', 
                   param_grid = param_grid,
                  descriptors_dict=descriptors_dict_pca, type = 'PCA')
# Out:
# 100%|██████████| 50/50 [00:53<00:00,  1.06s/trial, best loss: 1.5137866375010356]
# {'alpha': 0.13585023600694035, 'threshold': 0.3345029073600816}
# Loss is 1.5137866375010356
# Standard deviation is 0.0
# 100%|██████████| 50/50 [00:48<00:00,  1.02trial/s, best loss: 1.493797860212779]
# {'alpha': 0.13755908907449418, 'threshold': 0.34190739806114323}
# Loss is 1.493797860212779
# Standard deviation is 0.0

# %% [markdown]
# Let's continue with other models. The first one will be
# **Random Forest Classification**

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),('randomforest', RandomForestRegressor(n_jobs = -1))])

# %%
space={'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
    'randomforest__max_depth':hp.randint('max_depth',1,25),  'randomforest__max_features':hp.choice('max_features', [None, 'sqrt', 'log2']),
       'randomforest__min_samples_split':hp.randint('min_samples_split', 2, 8),
       'randomforest__min_samples_leaf': hp.randint('min_samples_leaf', 2, 10),
      'randomforest__n_estimators':hp.randint('n_estimators',10, 150),
      'randomforest__criterion': hp.choice('criterion', ["squared_error", "absolute_error", "friedman_mse"])}

# %%
calculate_to_score(pipe, estimator_name = 'Random Forest', param_grid =  space,
                   descriptors_dict=descriptors_dict,
                   target=target,type = 'Full')
# Out:
# 100%|██████████| 50/50 [09:39<00:00, 11.59s/trial, best loss: 1.1754733481628228]
# {'criterion': 2, 'max_depth': 23, 'max_features': 0, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 147, 'threshold': 0.13945553169892744}
# Loss is 1.1754733481628228
# Standard deviation is 0.0
# 100%|██████████| 50/50 [18:30<00:00, 22.20s/trial, best loss: 1.049285832491678]
# {'criterion': 0, 'max_depth': 15, 'max_features': 0, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 55, 'threshold': 0.18464427588781873}
# Loss is 1.049285832491678
# Standard deviation is 0.0

# %%
calculate_to_score(pipe, estimator_name = 'Random Forest', param_grid =  space,
                   descriptors_dict=descriptors_dict_pca,
                   target=target,                   type = 'PCA')
# Out:
# 100%|██████████| 50/50 [07:05<00:00,  8.51s/trial, best loss: 1.1679004055789914]
# {'criterion': 0, 'max_depth': 22, 'max_features': 0, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 114, 'threshold': 0.2914036779390856}
# Loss is 1.1679004055789914
# Standard deviation is 0.0
# 100%|██████████| 50/50 [11:47<00:00, 14.16s/trial, best loss: 1.064420796536452]
# {'criterion': 2, 'max_depth': 15, 'max_features': 0, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 99, 'threshold': 0.3197607336303466}
# Loss is 1.064420796536452
# Standard deviation is 0.0

# %% [markdown]
# **XGBoost**

# %%
pipe = Pipeline([('varsel', VarianceThreshold()),('xgbclassifier', XGBRegressor(n_jobs = -1))])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
        'xgbclassifier__n_estimators':hp.randint('n_estimators', 1, 30),
         'xgbclassifier__learning_rate': hp.loguniform('learning_rate', low = -4*np.log(10), high  = 2*np.log(10)),
         'xgbclassifier__reg_alpha':hp.loguniform(label = 'reg_alpha', low = -4*np.log(10), high  = 2*np.log(10)),
         'xgbclassifier__max_depth':hp.randint('max_depth', 1, 100)}

# %%
calculate_to_score(pipe, estimator_name='Gradient boosting', param_grid = space,
                   descriptors_dict=descriptors_dict,
                   target=target,
                   type = 'Full')
# Out:
#  58%|█████▊    | 29/50 [14:34<10:46, 30.76s/trial, best loss: 1.165557530184402]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
# ...
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#  96%|█████████▌| 48/50 [20:41<00:40, 20.15s/trial, best loss: 1.02707851623097]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
# 100%|██████████| 50/50 [21:21<00:00, 25.63s/trial, best loss: 1.02707851623097]
# {'learning_rate': 0.17391836545912331, 'max_depth': 58, 'n_estimators': 29, 'reg_alpha': 0.35276411605231844, 'threshold': 0.3240689146087459}
# Loss is nan
# Standard deviation is nan

# %%
calculate_to_score(pipe, estimator_name='Gradient boosting', param_grid = space,
                   descriptors_dict=descriptors_dict_pca,
                   target=target,
                   type = 'PCA')
# Out:
#  50%|█████     | 25/50 [12:36<12:58, 31.13s/trial, best loss: 1.1632645109984519]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
# ...
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains infinity or a value too large for dtype('float32').
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains infinity or a value too large for dtype('float64').
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains infinity or a value too large for dtype('float32').
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains infinity or a value too large for dtype('float32').
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains infinity or a value too large for dtype('float64').
#
#   warnings.warn(
#  88%|████████▊ | 44/50 [22:15<03:07, 31.19s/trial, best loss: 1.1632645109984519]
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 581, in root_mean_squared_error
#     mean_squared_error(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 506, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains infinity or a value too large for dtype('float32').
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 216, in mean_absolute_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#                                           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains infinity or a value too large for dtype('float32').
#
#   warnings.warn(
#
# C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:1000: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 139, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 1204, in r2_score
#     _, y_true, y_pred, multioutput = _check_reg_targets(
#                                      ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py", line 113, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 1064, in check_array
#     _assert_all_finite(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 123, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\T.Unusov\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py", line 172, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# 100%|██████████| 50/50 [24:56<00:00, 29.93s/trial, best loss: 1.1632645109984519]
# {'learning_rate': 0.349972196877612, 'max_depth': 37, 'n_estimators': 22, 'reg_alpha': 0.0453251826627949, 'threshold': 0.029988809793473736}
# Loss is nan
# Standard deviation is nan
# 100%|██████████| 50/50 [24:00<00:00, 28.81s/trial, best loss: 1.057499619128518]
# {'learning_rate': 0.14994785875242625, 'max_depth': 96, 'n_estimators': 22, 'reg_alpha': 0.14837054740994501, 'threshold': 0.061469244509888665}
# Loss is 1.057499619128518
# Standard deviation is 0.0

# %% [markdown]
# **SVM**

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('model_sel',SelectFromModel(Lasso(max_iter=10000))),
                 ('svc', SVR())])

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('svc', SVR())])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
         #'model_sel__estimator__alpha':hp.loguniform(label = 'alpha', low = -1, high =2),
    'svc__C':hp.loguniform('C', -3*np.log(10), 2*np.log(10)),
         'svc__kernel':hp.choice('kernel', ['rbf','poly','linear', 'sigmoid']),
         'svc__degree':hp.choice('degree', [2,3]),
         'svc__gamma':hp.choice('gamma', ['scale', 'auto']),
         'svc__coef0':hp.loguniform('coef0', -3*np.log(10), 0*np.log(10))}

# %%
calculate_to_score(pipe, estimator_name = 'SVC', param_grid = space, descriptors_dict=descriptors_dict, target = target, type = 'Full')
# Out:
# 100%|██████████| 50/50 [01:45<00:00,  2.12s/trial, best loss: 1.5236846091242076]
# {'C': 4.844935693869195, 'coef0': 0.1871949993681014, 'degree': 0, 'gamma': 0, 'kernel': 0, 'threshold': 0.2723932271668955}
# Loss is 1.5236846091242076
# Standard deviation is 0.0
# 100%|██████████| 50/50 [01:15<00:00,  1.51s/trial, best loss: 1.4470811804433912]
# {'C': 99.48337544790445, 'coef0': 0.04832973649581515, 'degree': 1, 'gamma': 0, 'kernel': 0, 'threshold': 0.2799137046333385}
# Loss is 1.4470811804433912
# Standard deviation is 0.0

# %%
calculate_to_score(pipe, estimator_name = 'SVC', param_grid = space, descriptors_dict=descriptors_dict_pca, target = target, type = 'PCA')
# Out:
# 100%|██████████| 50/50 [01:05<00:00,  1.30s/trial, best loss: 1.534455496263802]
# {'C': 0.021850033260202333, 'coef0': 0.013667984830696074, 'degree': 1, 'gamma': 1, 'kernel': 2, 'threshold': 0.26010838294933036}
# Loss is 1.534455496263802
# Standard deviation is 0.0
# 100%|██████████| 50/50 [01:36<00:00,  1.92s/trial, best loss: 1.4639169901368179]
# {'C': 97.49099974770658, 'coef0': 0.2151361813446453, 'degree': 0, 'gamma': 1, 'kernel': 0, 'threshold': 0.11645548877061936}
# Loss is 1.4639169901368179
# Standard deviation is 0.0

# %% [markdown]
# **KNearestneighbors**

# %%
pipe = Pipeline([('varsel',VarianceThreshold()),
                 ('scaler',StandardScaler()),
                 ('kneighborsregressor', KNeighborsRegressor())])

# %%
space = {'varsel__threshold':hp.uniform(label = 'threshold', low = 0, high  = 0.4),
    'kneighborsregressor__n_neighbors':hp.randint('n_neighbors',1, 10),
         'kneighborsregressor__weights':hp.choice('weights', ['uniform', 'distance']),
         'kneighborsregressor__metric':hp.choice('metric', ['minkowski', 'chebyshev', 'cosine', 'euclidean'])}

# %%
calculate_to_score(pipe, estimator_name='KMeans', param_grid=space, 
                   descriptors_dict=descriptors_dict, target=target, type = 'Full')
# Out:
# 100%|██████████| 50/50 [00:45<00:00,  1.11trial/s, best loss: 1.4641874926334462]
# {'metric': 0, 'n_neighbors': 4, 'threshold': 0.1889843844291385, 'weights': 0}
# Loss is 1.4641874926334462
# Standard deviation is 0.0
# 100%|██████████| 50/50 [00:47<00:00,  1.05trial/s, best loss: 1.37977577155544]
# {'metric': 1, 'n_neighbors': 8, 'threshold': 0.08564635584489816, 'weights': 1}
# Loss is 1.37977577155544
# Standard deviation is 0.0

# %%
calculate_to_score(pipe, estimator_name='KMeans', param_grid=space, 
                   descriptors_dict=descriptors_dict_pca, target=target, type = 'PCA')
# Out:
# 100%|██████████| 50/50 [00:46<00:00,  1.08trial/s, best loss: 1.472447147932726]
# {'metric': 0, 'n_neighbors': 4, 'threshold': 0.21366382469103745, 'weights': 0}
# Loss is 1.472447147932726
# Standard deviation is 0.0
# 100%|██████████| 50/50 [00:48<00:00,  1.03trial/s, best loss: 1.381918734577406]
# {'metric': 1, 'n_neighbors': 8, 'threshold': 0.2768285720671153, 'weights': 1}
# Loss is 1.381918734577406
# Standard deviation is 0.0

# %% [markdown]
# Let's save results into pickle file and show the final scores model in readable format

# %%
pd.DataFrame(scores)
# Out:
#    Descriptors          Estimator Full or PCA   RMSE_CV  Stddev_RMSE_CV  \
# 0     Standard   Lasso regression        Full  1.578429             0.0
# 1        Padel   Lasso regression        Full  1.687047             0.0
# 2     Standard   Lasso regression        Full  1.499773             0.0
# 3        Padel   Lasso regression        Full  1.492038             0.0
# 4     Standard   Lasso Regression         PCA  1.513787             0.0
# 5        Padel   Lasso Regression         PCA  1.493798             0.0
# 6     Standard      Random Forest        Full  1.175473             0.0
# 7        Padel      Random Forest        Full  1.049286             0.0
# 8     Standard      Random Forest         PCA  1.167900             0.0
# 9        Padel      Random Forest         PCA  1.064421             0.0
# 10    Standard  Gradient boosting        Full       NaN             NaN
# 11       Padel  Gradient boosting        Full       NaN             NaN
# 12    Standard  Gradient boosting         PCA       NaN             NaN
# 13       Padel  Gradient boosting         PCA  1.057500             0.0
# 14    Standard                SVC        Full  1.523685             0.0
# 15       Padel                SVC        Full  1.447081             0.0
# 16    Standard                SVC         PCA  1.534455             0.0
# 17       Padel                SVC         PCA  1.463917             0.0
# 18    Standard             KMeans        Full  1.464187             0.0
# 19       Padel             KMeans        Full  1.379776             0.0
# 20    Standard             KMeans         PCA  1.472447             0.0
# 21       Padel             KMeans         PCA  1.381919             0.0
#
#                                                 R2_CV    MAE_CV  RMSE_test  \
# 0   [0.12797129043427435, 0.15034319996017775, 0.1...  1.282712   1.339671
# 1   [-0.01598033299372248, 0.048355736115403, 0.05...  1.389696   1.483558
# 2   [0.2015240556438822, 0.2543255682414318, 0.182...  1.188802   1.483558
# 3   [0.2552722737192392, 0.2614736720192792, 0.185...  1.182984   1.295058
# 4   [0.23064495102903904, 0.23354781338410358, 0.1...  1.216832   1.288490
# 5   [0.2586912348305602, 0.274038414175963, 0.1763...  1.173370   1.483558
# 6   [0.6394994887992776, 0.48136131720759434, 0.49...  0.870895   1.243846
# 7   [0.7337386151712002, 0.4840910889427654, 0.525...  0.739827   1.159585
# 8   [0.6467149004752873, 0.5274230355809947, 0.454...  0.860841   1.048926
# 9   [0.7268162884153131, 0.4707488739047203, 0.527...  0.757477   1.227249
# 10  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...       NaN   1.141285
# 11  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...       NaN   1.456607
# 12  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...       NaN   1.372424
# 13  [0.7782738594613363, 0.46197219515543086, 0.58...  0.696166   1.125191
# 14  [0.1350247500806615, 0.3473393502399277, 0.148...  1.061739   1.446804
# 15  [0.38768994416188773, 0.43868161366516867, 0.0...  0.956771  12.857894
# 16  [0.18688755187741757, 0.34740607202430696, 0.1...  1.090922   1.538771
# 17  [0.3617576572970881, 0.40039693806691024, 0.05...  0.966956   1.333262
# 18  [0.4792688532109448, 0.06873836177078807, 0.03...  1.094148   1.302492
# 19  [0.4512237101237665, 0.41854742652953736, 0.16...  1.046823   1.346822
# 20  [0.48317153449641104, 0.025733030089044262, 0....  1.097280   1.647674
# 21  [0.4391747000357452, 0.3928330251412431, 0.152...  1.042835   1.343752
#
#     MAE_test    R2_test
# 0   1.089835   0.182534
# 1   1.221858  -0.002496
# 2   1.221858  -0.002496
# 3   1.034896   0.236073
# 4   1.044560   0.243802
# 5   1.221858  -0.002496
# 6   0.956968   0.295296
# 7   0.848846   0.387538
# 8   0.773140   0.498855
# 9   0.944525   0.313976
# 10  0.887558   0.406717
# 11  1.198407   0.033597
# 12  1.117468   0.142074
# 13  0.870456   0.423332
# 14  0.991132   0.046561
# 15  5.968819 -74.303153
# 16  1.149724  -0.078504
# 17  0.970971   0.190337
# 18  0.948398   0.227277
# 19  1.101228   0.173783
# 20  1.073587  -0.236562
# 21  0.880809   0.177546

# %%
scores_df = pd.DataFrame(scores)

# %%
scores_df['R2_CV'] = scores_df['R2_CV'].apply(np.mean)

# %%
scores = scores_df.to_dict()

# %%
with open('score_regression_random.pickle', 'wb') as output:
    pickle.dump(scores, output)
