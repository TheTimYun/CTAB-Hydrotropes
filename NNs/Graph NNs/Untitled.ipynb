# %%
import pickle
import pandas as pd
from hyperopt import hp, tpe, Trials, fmin, STATUS_OK

# %%
with open('best_params.pickle', 'rb') as inp:
    best_params = pickle.load(inp)

# %%
trials = best_params[1]

# %%
valid_trial_list = [trial for trial in trials if trial['result']['status'] == STATUS_OK]

# %%
valid_trial_list
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': -0.7608500480651855,
#    'status': 'ok',
#    'accuracy': 0.7608500480651855,
#    'f1': 0.7444980859756469,
#    'recall': 0.7269375443458557,
#    'precision': 0.7388795614242554},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [0], 'lr': [0], 'n1': [0], 'n2': [0]},
#    'vals': {'epochs': [39],
#     'lr': [0.0028145232090926713],
#     'n1': [85],
#     'n2': [27]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 7, 3, 3, 105000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 7, 12, 9, 784000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': -0.21809524297714233,
#    'status': 'ok',
#    'accuracy': 0.21809524297714233,
#    'f1': 0.5253555357456208,
#    'recall': 0.4,
#    'precision': 0.2818363308906555},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [1], 'lr': [1], 'n1': [1], 'n2': [1]},
#    'vals': {'epochs': [78],
#     'lr': [0.003736725877838588],
#     'n1': [807],
#     'n2': [576]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 7, 12, 9, 789000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 7, 30, 49, 503000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': -0.3375649392604828,
#    'status': 'ok',
#    'accuracy': 0.3375649392604828,
#    'f1': 0.5422649204730987,
#    'recall': 0.5079365134239197,
#    'precision': 0.393334698677063},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [2], 'lr': [2], 'n1': [2], 'n2': [2]},
#    'vals': {'epochs': [94],
#     'lr': [0.007790100378285924],
#     'n1': [766],
#     'n2': [683]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 7, 30, 49, 505000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 7, 53, 12, 687000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': -0.11809524297714233,
#    'status': 'ok',
#    'accuracy': 0.11809524297714233,
#    'f1': 0.513705050945282,
#    'recall': 0.2,
#    'precision': 0.1485029935836792},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [3], 'lr': [3], 'n1': [3], 'n2': [3]},
#    'vals': {'epochs': [37],
#     'lr': [0.007448106131467176],
#     'n1': [114],
#     'n2': [564]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 7, 53, 12, 689000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 8, 1, 57, 47000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': -0.7359899044036865,
#    'status': 'ok',
#    'accuracy': 0.7359899044036865,
#    'f1': 0.6119207859039306,
#    'recall': 0.5035579651594162,
#    'precision': 0.5309074223041534},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [4], 'lr': [4], 'n1': [4], 'n2': [4]},
#    'vals': {'epochs': [35],
#     'lr': [0.008825502859872188],
#     'n1': [598],
#     'n2': [291]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 8, 1, 57, 49000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 8, 10, 37, 196000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': -0.7181650757789612,
#    'status': 'ok',
#    'accuracy': 0.7181650757789612,
#    'f1': 0.6988178133964539,
#    'recall': 0.7072719156742096,
#    'precision': 0.690237534046173},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [5], 'lr': [5], 'n1': [5], 'n2': [5]},
#    'vals': {'epochs': [69],
#     'lr': [0.0016522359716127676],
#     'n1': [405],
#     'n2': [220]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 8, 10, 37, 198000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 8, 27, 34, 397000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': -0.46200475096702576,
#    'status': 'ok',
#    'accuracy': 0.46200475096702576,
#    'f1': 0.5723495364189148,
#    'recall': 0.7554019451141357,
#    'precision': 0.560404098033905},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [6], 'lr': [6], 'n1': [6], 'n2': [6]},
#    'vals': {'epochs': [97],
#     'lr': [0.004526689494447874],
#     'n1': [40],
#     'n2': [654]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 8, 27, 34, 400000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 8, 50, 8, 677000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': -0.23013182878494262,
#    'status': 'ok',
#    'accuracy': 0.23013182878494262,
#    'f1': 0.4577350735664368,
#    'recall': 0.24444444477558136,
#    'precision': 0.17777777314186097},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [7], 'lr': [7], 'n1': [7], 'n2': [7]},
#    'vals': {'epochs': [55],
#     'lr': [0.003615973310988523],
#     'n1': [332],
#     'n2': [706]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 8, 50, 8, 680000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 9, 3, 49, 899000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': -0.44174360036849974,
#    'status': 'ok',
#    'accuracy': 0.44174360036849974,
#    'f1': 0.5566692411899566,
#    'recall': 0.7035573124885559,
#    'precision': 0.535712206363678},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [8], 'lr': [8], 'n1': [8], 'n2': [8]},
#    'vals': {'epochs': [78],
#     'lr': [0.007017448591674476],
#     'n1': [931],
#     'n2': [250]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 9, 3, 49, 901000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 9, 22, 44, 228000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': -0.6745385348796844,
#    'status': 'ok',
#    'accuracy': 0.6745385348796844,
#    'f1': 0.7142660856246948,
#    'recall': 0.876306164264679,
#    'precision': 0.7557412266731263},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [9], 'lr': [9], 'n1': [9], 'n2': [9]},
#    'vals': {'epochs': [88],
#     'lr': [0.004709133471688591],
#     'n1': [337],
#     'n2': [109]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 9, 22, 44, 229000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 9, 43, 58, 981000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': -0.36665105223655703,
#    'status': 'ok',
#    'accuracy': 0.36665105223655703,
#    'f1': 0.5846289277076722,
#    'recall': 0.5456733226776123,
#    'precision': 0.4323098659515381},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [10], 'lr': [10], 'n1': [10], 'n2': [10]},
#    'vals': {'epochs': [70],
#     'lr': [0.007622911322796785],
#     'n1': [815],
#     'n2': [359]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 9, 43, 58, 982000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 10, 0, 41, 843000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': -0.7255712687969208,
#    'status': 'ok',
#    'accuracy': 0.7255712687969208,
#    'f1': 0.630128699541092,
#    'recall': 0.6334705084562302,
#    'precision': 0.588548994064331},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [11], 'lr': [11], 'n1': [11], 'n2': [11]},
#    'vals': {'epochs': [16],
#     'lr': [0.008494414364278221],
#     'n1': [323],
#     'n2': [622]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 10, 0, 41, 846000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 10, 4, 41, 865000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': -0.4828601241111755,
#    'status': 'ok',
#    'accuracy': 0.4828601241111755,
#    'f1': 0.6045990705490112,
#    'recall': 0.6518840610980987,
#    'precision': 0.5272667348384857},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [12], 'lr': [12], 'n1': [12], 'n2': [12]},
#    'vals': {'epochs': [16],
#     'lr': [0.008619723248836152],
#     'n1': [56],
#     'n2': [787]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 10, 4, 41, 868000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 10, 8, 30, 176000)},
#  {'state': 2,
#   'tid': 13,
#   'spec': None,
#   'result': {'loss': -0.6763248860836029,
#    'status': 'ok',
#    'accuracy': 0.6763248860836029,
#    'f1': 0.6386183738708496,
#    'recall': 0.7648763477802276,
#    'precision': 0.6536472201347351},
#   'misc': {'tid': 13,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [13], 'lr': [13], 'n1': [13], 'n2': [13]},
#    'vals': {'epochs': [11],
#     'lr': [0.003913356113340831],
#     'n1': [473],
#     'n2': [229]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 10, 8, 30, 178000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 10, 11, 14, 74000)},
#  {'state': 2,
#   'tid': 14,
#   'spec': None,
#   'result': {'loss': -0.30582627058029177,
#    'status': 'ok',
#    'accuracy': 0.30582627058029177,
#    'f1': 0.49657002091407776,
#    'recall': 0.6,
#    'precision': 0.4004658699035645},
#   'misc': {'tid': 14,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [14], 'lr': [14], 'n1': [14], 'n2': [14]},
#    'vals': {'epochs': [95],
#     'lr': [0.007332100231019669],
#     'n1': [689],
#     'n2': [549]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 10, 11, 14, 76000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 10, 34, 1, 384000)},
#  {'state': 2,
#   'tid': 15,
#   'spec': None,
#   'result': {'loss': -0.3055720806121826,
#    'status': 'ok',
#    'accuracy': 0.3055720806121826,
#    'f1': 0.49671161770820615,
#    'recall': 0.6,
#    'precision': 0.4004485487937927},
#   'misc': {'tid': 15,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [15], 'lr': [15], 'n1': [15], 'n2': [15]},
#    'vals': {'epochs': [40],
#     'lr': [0.004386520322428077],
#     'n1': [661],
#     'n2': [495]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 10, 34, 1, 387000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 10, 43, 58, 370000)},
#  {'state': 2,
#   'tid': 16,
#   'spec': None,
#   'result': {'loss': -0.5236059963703156,
#    'status': 'ok',
#    'accuracy': 0.5236059963703156,
#    'f1': 0.5671916961669922,
#    'recall': 0.6345454514026642,
#    'precision': 0.5206680655479431},
#   'misc': {'tid': 16,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [16], 'lr': [16], 'n1': [16], 'n2': [16]},
#    'vals': {'epochs': [38],
#     'lr': [0.009954889979520345],
#     'n1': [748],
#     'n2': [330]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 10, 43, 58, 372000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 10, 53, 4, 510000)},
#  {'state': 2,
#   'tid': 17,
#   'spec': None,
#   'result': {'loss': -0.6365475296974182,
#    'status': 'ok',
#    'accuracy': 0.6365475296974182,
#    'f1': 0.6524857401847839,
#    'recall': 0.7500819027423858,
#    'precision': 0.6253848016262055},
#   'misc': {'tid': 17,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [17], 'lr': [17], 'n1': [17], 'n2': [17]},
#    'vals': {'epochs': [23],
#     'lr': [0.009285698221429406],
#     'n1': [810],
#     'n2': [140]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 10, 53, 4, 511000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 10, 58, 35, 96000)},
#  {'state': 2,
#   'tid': 18,
#   'spec': None,
#   'result': {'loss': -0.5522807121276856,
#    'status': 'ok',
#    'accuracy': 0.5522807121276856,
#    'f1': 0.6607905030250549,
#    'recall': 0.6857142925262452,
#    'precision': 0.5854864239692688},
#   'misc': {'tid': 18,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [18], 'lr': [18], 'n1': [18], 'n2': [18]},
#    'vals': {'epochs': [75],
#     'lr': [0.002001116352767002],
#     'n1': [455],
#     'n2': [398]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 10, 58, 35, 99000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 11, 17, 5, 27000)},
#  {'state': 2,
#   'tid': 19,
#   'spec': None,
#   'result': {'loss': -0.7256358981132507,
#    'status': 'ok',
#    'accuracy': 0.7256358981132507,
#    'f1': 0.6437179565429687,
#    'recall': 0.5758265495300293,
#    'precision': 0.5977498650550842},
#   'misc': {'tid': 19,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [19], 'lr': [19], 'n1': [19], 'n2': [19]},
#    'vals': {'epochs': [19],
#     'lr': [0.004789139478304775],
#     'n1': [913],
#     'n2': [533]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 11, 17, 5, 29000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 11, 21, 43, 160000)},
#  {'state': 2,
#   'tid': 20,
#   'spec': None,
#   'result': {'loss': -0.749692189693451,
#    'status': 'ok',
#    'accuracy': 0.749692189693451,
#    'f1': 0.7497442722320556,
#    'recall': 0.752981674671173,
#    'precision': 0.7453707575798034},
#   'misc': {'tid': 20,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [20], 'lr': [20], 'n1': [20], 'n2': [20]},
#    'vals': {'epochs': [35],
#     'lr': [0.00017879468835495845],
#     'n1': [101],
#     'n2': [25]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 11, 21, 43, 169000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 11, 29, 53, 915000)},
#  {'state': 2,
#   'tid': 21,
#   'spec': None,
#   'result': {'loss': -0.7687265276908875,
#    'status': 'ok',
#    'accuracy': 0.7687265276908875,
#    'f1': 0.7512495040893554,
#    'recall': 0.7642355501651764,
#    'precision': 0.7415161609649659},
#   'misc': {'tid': 21,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [21], 'lr': [21], 'n1': [21], 'n2': [21]},
#    'vals': {'epochs': [7],
#     'lr': [0.00028285838361894123],
#     'n1': [883],
#     'n2': [887]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 11, 29, 53, 921000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 11, 31, 39, 231000)},
#  {'state': 2,
#   'tid': 22,
#   'spec': None,
#   'result': {'loss': -0.8031000375747681,
#    'status': 'ok',
#    'accuracy': 0.8031000375747681,
#    'f1': 0.721342670917511,
#    'recall': 0.6678341507911683,
#    'precision': 0.7032795786857605},
#   'misc': {'tid': 22,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [22], 'lr': [22], 'n1': [22], 'n2': [22]},
#    'vals': {'epochs': [39],
#     'lr': [0.00012751361479088606],
#     'n1': [408],
#     'n2': [29]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 11, 31, 39, 237000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 11, 41, 15, 850000)},
#  {'state': 2,
#   'tid': 23,
#   'spec': None,
#   'result': {'loss': -0.7362888574600219,
#    'status': 'ok',
#    'accuracy': 0.7362888574600219,
#    'f1': 0.6746972680091858,
#    'recall': 0.6711129009723663,
#    'precision': 0.6640491127967835},
#   'misc': {'tid': 23,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [23], 'lr': [23], 'n1': [23], 'n2': [23]},
#    'vals': {'epochs': [22],
#     'lr': [0.0004413907335722024],
#     'n1': [556],
#     'n2': [404]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 11, 41, 15, 856000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 11, 46, 39, 506000)},
#  {'state': 2,
#   'tid': 24,
#   'spec': None,
#   'result': {'loss': -0.5610079526901245,
#    'status': 'ok',
#    'accuracy': 0.5610079526901245,
#    'f1': 0.6109919428825379,
#    'recall': 0.5454927951097488,
#    'precision': 0.49391351342201234},
#   'misc': {'tid': 24,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [24], 'lr': [24], 'n1': [24], 'n2': [24]},
#    'vals': {'epochs': [80],
#     'lr': [0.00592839044599968],
#     'n1': [721],
#     'n2': [153]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 11, 46, 39, 512000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 12, 5, 49, 153000)},
#  {'state': 2,
#   'tid': 25,
#   'spec': None,
#   'result': {'loss': -0.7837606847286225,
#    'status': 'ok',
#    'accuracy': 0.7837606847286225,
#    'f1': 0.5906378567218781,
#    'recall': 0.5056571036577224,
#    'precision': 0.4917040839791298},
#   'misc': {'tid': 25,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [25], 'lr': [25], 'n1': [25], 'n2': [25]},
#    'vals': {'epochs': [7],
#     'lr': [0.0010233372719368663],
#     'n1': [986],
#     'n2': [800]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 12, 5, 49, 159000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 12, 7, 34, 180000)},
#  {'state': 2,
#   'tid': 26,
#   'spec': None,
#   'result': {'loss': -0.5924590468406677,
#    'status': 'ok',
#    'accuracy': 0.5924590468406677,
#    'f1': 0.7235827326774598,
#    'recall': 0.6946485996246338,
#    'precision': 0.6308066844940186},
#   'misc': {'tid': 26,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [26], 'lr': [26], 'n1': [26], 'n2': [26]},
#    'vals': {'epochs': [91],
#     'lr': [0.001309074812667135],
#     'n1': [408],
#     'n2': [686]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 12, 7, 34, 186000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 12, 29, 59, 594000)},
#  {'state': 2,
#   'tid': 27,
#   'spec': None,
#   'result': {'loss': -0.7218511462211609,
#    'status': 'ok',
#    'accuracy': 0.7218511462211609,
#    'f1': 0.7338756442070007,
#    'recall': 0.7700086116790772,
#    'precision': 0.7422748923301696},
#   'misc': {'tid': 27,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [27], 'lr': [27], 'n1': [27], 'n2': [27]},
#    'vals': {'epochs': [82],
#     'lr': [0.0010596874701407776],
#     'n1': [62],
#     'n2': [268]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 12, 29, 59, 600000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 12, 48, 58, 466000)},
#  {'state': 2,
#   'tid': 28,
#   'spec': None,
#   'result': {'loss': -0.6665983557701111,
#    'status': 'ok',
#    'accuracy': 0.6665983557701111,
#    'f1': 0.6580672144889832,
#    'recall': 0.7298260867595673,
#    'precision': 0.6714152693748474},
#   'misc': {'tid': 28,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [28], 'lr': [28], 'n1': [28], 'n2': [28]},
#    'vals': {'epochs': [89],
#     'lr': [0.0028286492837112593],
#     'n1': [443],
#     'n2': [29]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 12, 48, 58, 472000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 13, 10, 41, 456000)},
#  {'state': 2,
#   'tid': 29,
#   'spec': None,
#   'result': {'loss': -0.3098993360996246,
#    'status': 'ok',
#    'accuracy': 0.3098993360996246,
#    'f1': 0.5023423552513122,
#    'recall': 0.5777777791023254,
#    'precision': 0.39885387420654295},
#   'misc': {'tid': 29,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [29], 'lr': [29], 'n1': [29], 'n2': [29]},
#    'vals': {'epochs': [46],
#     'lr': [0.0025662810525614588],
#     'n1': [164],
#     'n2': [965]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 13, 10, 41, 461000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 13, 21, 46, 720000)},
#  {'state': 2,
#   'tid': 30,
#   'spec': None,
#   'result': {'loss': -0.5347635388374329,
#    'status': 'ok',
#    'accuracy': 0.5347635388374329,
#    'f1': 0.5516520977020264,
#    'recall': 1.0,
#    'precision': 0.6917283058166503},
#   'misc': {'tid': 30,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [30], 'lr': [30], 'n1': [30], 'n2': [30]},
#    'vals': {'epochs': [49],
#     'lr': [0.00589317993844364],
#     'n1': [545],
#     'n2': [774]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 13, 21, 46, 725000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 13, 33, 43, 474000)},
#  {'state': 2,
#   'tid': 31,
#   'spec': None,
#   'result': {'loss': -0.5026135087013245,
#    'status': 'ok',
#    'accuracy': 0.5026135087013245,
#    'f1': 0.6141743063926697,
#    'recall': 0.32605578303337096,
#    'precision': 0.3584481358528137},
#   'misc': {'tid': 31,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [31], 'lr': [31], 'n1': [31], 'n2': [31]},
#    'vals': {'epochs': [92],
#     'lr': [0.002698713475419014],
#     'n1': [276],
#     'n2': [575]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 13, 33, 43, 480000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 13, 55, 56, 307000)},
#  {'state': 2,
#   'tid': 32,
#   'spec': None,
#   'result': {'loss': -0.6992475748062134,
#    'status': 'ok',
#    'accuracy': 0.6992475748062134,
#    'f1': 0.7279787302017212,
#    'recall': 0.7824033975601197,
#    'precision': 0.7350296378135681},
#   'misc': {'tid': 32,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [32], 'lr': [32], 'n1': [32], 'n2': [32]},
#    'vals': {'epochs': [86],
#     'lr': [0.0005787114573192398],
#     'n1': [925],
#     'n2': [443]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 13, 55, 56, 313000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 14, 16, 46, 42000)},
#  {'state': 2,
#   'tid': 33,
#   'spec': None,
#   'result': {'loss': -0.7546521306037903,
#    'status': 'ok',
#    'accuracy': 0.7546521306037903,
#    'f1': 0.6581233263015747,
#    'recall': 0.6538974285125733,
#    'precision': 0.6102965772151947},
#   'misc': {'tid': 33,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [33], 'lr': [33], 'n1': [33], 'n2': [33]},
#    'vals': {'epochs': [39],
#     'lr': [0.00199797208912566],
#     'n1': [986],
#     'n2': [950]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 14, 16, 46, 48000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 14, 26, 14, 743000)},
#  {'state': 2,
#   'tid': 34,
#   'spec': None,
#   'result': {'loss': -0.8024409294128418,
#    'status': 'ok',
#    'accuracy': 0.8024409294128418,
#    'f1': 0.7362764358520508,
#    'recall': 0.6490383446216583,
#    'precision': 0.7091673374176025},
#   'misc': {'tid': 34,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [34], 'lr': [34], 'n1': [34], 'n2': [34]},
#    'vals': {'epochs': [52],
#     'lr': [0.0008978063268784433],
#     'n1': [583],
#     'n2': [677]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 14, 26, 14, 749000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 14, 39, 10, 567000)},
#  {'state': 2,
#   'tid': 35,
#   'spec': None,
#   'result': {'loss': -0.4245678007602692,
#    'status': 'ok',
#    'accuracy': 0.4245678007602692,
#    'f1': 0.5417294800281525,
#    'recall': 0.8,
#    'precision': 0.5519719004631043},
#   'misc': {'tid': 35,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [35], 'lr': [35], 'n1': [35], 'n2': [35]},
#    'vals': {'epochs': [52],
#     'lr': [0.0031637841672759],
#     'n1': [278],
#     'n2': [932]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 14, 39, 10, 573000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 14, 52, 3, 72000)},
#  {'state': 2,
#   'tid': 36,
#   'spec': None,
#   'result': {'loss': -0.2704096019268036,
#    'status': 'ok',
#    'accuracy': 0.2704096019268036,
#    'f1': 0.4299842655658722,
#    'recall': 0.6,
#    'precision': 0.37155277729034425},
#   'misc': {'tid': 36,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [36], 'lr': [36], 'n1': [36], 'n2': [36]},
#    'vals': {'epochs': [52],
#     'lr': [0.005298109239858215],
#     'n1': [238],
#     'n2': [555]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 14, 52, 3, 78000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 15, 4, 36, 128000)},
#  {'state': 2,
#   'tid': 37,
#   'spec': None,
#   'result': {'loss': -0.6353495359420777,
#    'status': 'ok',
#    'accuracy': 0.6353495359420777,
#    'f1': 0.6743192195892334,
#    'recall': 0.76157645881176,
#    'precision': 0.666949987411499},
#   'misc': {'tid': 37,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [37], 'lr': [37], 'n1': [37], 'n2': [37]},
#    'vals': {'epochs': [9],
#     'lr': [0.0018436307036799912],
#     'n1': [844],
#     'n2': [421]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 15, 4, 36, 133000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 15, 6, 48, 620000)},
#  {'state': 2,
#   'tid': 38,
#   'spec': None,
#   'result': {'loss': -0.5487396001815796,
#    'status': 'ok',
#    'accuracy': 0.5487396001815796,
#    'f1': 0.5948734641075134,
#    'recall': 0.626406928896904,
#    'precision': 0.5078770220279694},
#   'misc': {'tid': 38,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [38], 'lr': [38], 'n1': [38], 'n2': [38]},
#    'vals': {'epochs': [31],
#     'lr': [0.0033417340120908447],
#     'n1': [379],
#     'n2': [982]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 15, 6, 48, 626000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 15, 14, 30, 938000)},
#  {'state': 2,
#   'tid': 39,
#   'spec': None,
#   'result': {'loss': -0.794729483127594,
#    'status': 'ok',
#    'accuracy': 0.794729483127594,
#    'f1': 0.7217758417129516,
#    'recall': 0.6726517081260681,
#    'precision': 0.6874122679233551},
#   'misc': {'tid': 39,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [39], 'lr': [39], 'n1': [39], 'n2': [39]},
#    'vals': {'epochs': [6],
#     'lr': [0.0009135419467958998],
#     'n1': [633],
#     'n2': [126]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 15, 14, 30, 943000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 15, 16, 2, 204000)},
#  {'state': 2,
#   'tid': 40,
#   'spec': None,
#   'result': {'loss': -0.7066905260086059,
#    'status': 'ok',
#    'accuracy': 0.7066905260086059,
#    'f1': 0.6844241142272949,
#    'recall': 0.744435864686966,
#    'precision': 0.6888979196548461},
#   'misc': {'tid': 40,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [40], 'lr': [40], 'n1': [40], 'n2': [40]},
#    'vals': {'epochs': [27],
#     'lr': [0.0014944741090266059],
#     'n1': [86],
#     'n2': [751]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 15, 16, 2, 210000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 15, 22, 26, 391000)},
#  {'state': 2,
#   'tid': 41,
#   'spec': None,
#   'result': {'loss': -0.7380949258804321,
#    'status': 'ok',
#    'accuracy': 0.7380949258804321,
#    'f1': 0.744718337059021,
#    'recall': 0.7717489957809448,
#    'precision': 0.7493747234344482},
#   'misc': {'tid': 41,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [41], 'lr': [41], 'n1': [41], 'n2': [41]},
#    'vals': {'epochs': [43],
#     'lr': [4.027700490426587e-05],
#     'n1': [624],
#     'n2': [927]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 15, 22, 26, 397000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 15, 33, 6, 586000)},
#  {'state': 2,
#   'tid': 42,
#   'spec': None,
#   'result': {'loss': -0.6699091076850892,
#    'status': 'ok',
#    'accuracy': 0.6699091076850892,
#    'f1': 0.6517045259475708,
#    'recall': 0.7627067625522613,
#    'precision': 0.6600733399391174},
#   'misc': {'tid': 42,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [42], 'lr': [42], 'n1': [42], 'n2': [42]},
#    'vals': {'epochs': [81],
#     'lr': [0.0023545258893136094],
#     'n1': [95],
#     'n2': [551]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 15, 33, 6, 593000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 15, 52, 0, 750000)},
#  {'state': 2,
#   'tid': 43,
#   'spec': None,
#   'result': {'loss': -0.6086856484413147,
#    'status': 'ok',
#    'accuracy': 0.6086856484413147,
#    'f1': 0.5939906597137451,
#    'recall': 0.8810129284858703,
#    'precision': 0.6878335118293762},
#   'misc': {'tid': 43,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [43], 'lr': [43], 'n1': [43], 'n2': [43]},
#    'vals': {'epochs': [72],
#     'lr': [0.003924403106634325],
#     'n1': [710],
#     'n2': [105]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 15, 52, 0, 757000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 16, 9, 21, 948000)},
#  {'state': 2,
#   'tid': 44,
#   'spec': None,
#   'result': {'loss': -0.34198718667030337,
#    'status': 'ok',
#    'accuracy': 0.34198718667030337,
#    'f1': 0.5049956977367401,
#    'recall': 0.4019047625362873,
#    'precision': 0.28478810787200926},
#   'misc': {'tid': 44,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [44], 'lr': [44], 'n1': [44], 'n2': [44]},
#    'vals': {'epochs': [51],
#     'lr': [0.0066009925827112655],
#     'n1': [575],
#     'n2': [517]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 16, 9, 21, 954000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 16, 21, 49, 219000)},
#  {'state': 2,
#   'tid': 45,
#   'spec': None,
#   'result': {'loss': -0.7226772785186768,
#    'status': 'ok',
#    'accuracy': 0.7226772785186768,
#    'f1': 0.7222163558006287,
#    'recall': 0.8030352473258973,
#    'precision': 0.7392315864562988},
#   'misc': {'tid': 45,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [45], 'lr': [45], 'n1': [45], 'n2': [45]},
#    'vals': {'epochs': [10],
#     'lr': [0.0006443418831170818],
#     'n1': [454],
#     'n2': [818]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 16, 21, 49, 224000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 16, 24, 20, 129000)},
#  {'state': 2,
#   'tid': 46,
#   'spec': None,
#   'result': {'loss': -0.5154524683952332,
#    'status': 'ok',
#    'accuracy': 0.5154524683952332,
#    'f1': 0.6352773427963256,
#    'recall': 0.6557487964630127,
#    'precision': 0.5565535545349121},
#   'misc': {'tid': 46,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [46], 'lr': [46], 'n1': [46], 'n2': [46]},
#    'vals': {'epochs': [79],
#     'lr': [0.005320857550393555],
#     'n1': [783],
#     'n2': [960]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 16, 24, 20, 136000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 16, 43, 15, 451000)},
#  {'state': 2,
#   'tid': 47,
#   'spec': None,
#   'result': {'loss': -0.5437437653541565,
#    'status': 'ok',
#    'accuracy': 0.5437437653541565,
#    'f1': 0.5644190788269043,
#    'recall': 0.5280794322490692,
#    'precision': 0.45592887997627257},
#   'misc': {'tid': 47,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [47], 'lr': [47], 'n1': [47], 'n2': [47]},
#    'vals': {'epochs': [65],
#     'lr': [0.00808716566145873],
#     'n1': [81],
#     'n2': [204]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 16, 43, 15, 456000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 16, 58, 22, 597000)},
#  {'state': 2,
#   'tid': 48,
#   'spec': None,
#   'result': {'loss': -0.3404253363609314,
#    'status': 'ok',
#    'accuracy': 0.3404253363609314,
#    'f1': 0.5700157284736633,
#    'recall': 0.6,
#    'precision': 0.4336435556411743},
#   'misc': {'tid': 48,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [48], 'lr': [48], 'n1': [48], 'n2': [48]},
#    'vals': {'epochs': [83],
#     'lr': [0.004051910989052828],
#     'n1': [252],
#     'n2': [677]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 16, 58, 22, 603000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 17, 18, 36, 737000)},
#  {'state': 2,
#   'tid': 49,
#   'spec': None,
#   'result': {'loss': -0.7317352294921875,
#    'status': 'ok',
#    'accuracy': 0.7317352294921875,
#    'f1': 0.5837027966976166,
#    'recall': 0.5468421012163163,
#    'precision': 0.5130796678364277},
#   'misc': {'tid': 49,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'epochs': [49], 'lr': [49], 'n1': [49], 'n2': [49]},
#    'vals': {'epochs': [21],
#     'lr': [0.0022111178417486017],
#     'n1': [361],
#     'n2': [837]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2025, 4, 25, 17, 18, 36, 744000),
#   'refresh_time': datetime.datetime(2025, 4, 25, 17, 23, 54, 357000)}]
